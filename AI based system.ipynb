# %%
import import_ipynb
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression, RidgeClassifier
from pycaw.pycaw import AudioUtilities, IAudioEndpointVolume
from sklearn.model_selection import train_test_split
from cvzone.HandTrackingModule import HandDetector
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
from sklearn.pipeline import make_pipeline
from pynput.keyboard import Controller
import HandTrackingModule5 as htm1
import handTrackingModule as htm
from ctypes import cast, POINTER
from comtypes import CLSCTX_ALL
from PIL import ImageTk, Image
from itertools import groupby
import tkinter.messagebox
from time import sleep
import mediapipe as mp
from tkinter import *
import tkinter as tk
import pandas as pd
import tempfile, os
import numpy as np
import threading
import datetime
import pyttsx3
import sqlite3
import random
import pickle
import socket
import cvzone
import math
import time
import cv2
import csv
import os
import re

#decraration of mediapipe holistic solution for facial expressions and pose detections
mp_holistic = mp.solutions.holistic
holistic = mp_holistic.Holistic(static_image_mode=False, min_detection_confidence  = 0.5, min_tracking_confidence = 0.5)
#read coordinates which contains facial expressions and pose detections
df = pd.read_csv('coords21.csv')
df1 = pd.read_csv('coords11.csv')
 
#initializing coordinates in coords12 int0 x and y so that we can understand them
x1 = df1.drop('class', axis=1)
y1 = df1['class']

#initializing coordinates in coords12 int0 x and y so that we can understand them
x = df.drop('class', axis=1)
y = df['class']

#initializing pipelines with sklearn models
pipelines = {
    'mlp':make_pipeline(StandardScaler(), MLPClassifier()),
}
pipelines1 = {
    'mlp1':make_pipeline(StandardScaler(), MLPClassifier()),
}
pipelines2 = {
    'lr':make_pipeline(StandardScaler(), LogisticRegression()),
    'rc':make_pipeline(StandardScaler(), RidgeClassifier()),
    'rf':make_pipeline(StandardScaler(), RandomForestClassifier()),
    'gb':make_pipeline(StandardScaler(), GradientBoostingClassifier()),
}
#split x nad cordinates into x_train, x_test, y_train and y_train for training models and testing 
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 1234)

#split x nad cordinates into x_train, x_test, y_train and y_train for training models and testing 
x_train1, x_test1, y_train1, y_test1 = train_test_split(x1, y1, test_size = 0.3, random_state = 1234)


print("Loading..........")
print("Have a passion!!")

#fit models with our data('coordinates')
fit_models = {}
for algo, pipeline in pipelines.items():
    model = pipeline.fit(x_train, y_train)
    fit_models[algo] = model
#fit models with our data('coordinates')
fit_models1 = {}
for algo1, pipeline1 in pipelines1.items():
    model1 = pipeline1.fit(x_train1, y_train1)
    fit_models1[algo1] = model1

#fit_models['rc'].predict(x_test)

for algo, model in fit_models.items():
    yhat = model.predict(x_test)
    print(algo, accuracy_score(y_test, yhat))
    
fit_models['mlp'].predict(x_test)

for algo1, model1 in fit_models1.items():
    yhat1 = model1.predict(x_test1)
    print(algo1, accuracy_score(y_test1, yhat1))
    
fit_models1['mlp1'].predict(x_test1)

#creation of signing class 
class SigningDisplay:
    try:
        def __init__(self, user_name):
            #creation of python GUI
            self.root = Tk()
            self.root.title("FACIAL RECOGNITION SCREEN")
            self.root.geometry("13660x800+0+0")
            self.root.configure(bg='gainsboro')

            #creation of GUI frames
            mainFrame = Frame(self.root, bd=10, width=1350, height=700, relief=RIDGE)
            mainFrame.grid()
            mainFrame.place(rely = 0.5, relx = 0.5, anchor=CENTER)

            topFrame = Frame(mainFrame, bd=5, width=1340, height=50, relief=RIDGE)
            topFrame.grid(row=0, column=0)

            topFrame1 = Frame(mainFrame, bd=5, width=1340, height=45, relief=RIDGE)
            topFrame1.grid(row=2, column=0)

            topFrame2 = Frame(mainFrame, bd=5, width=1340, height=495, relief=RIDGE)
            topFrame2.grid(row=1, column=0)

            leftFrame = Frame(topFrame2, bd=5, width=650, height=562, padx=2, bg="gainsboro", relief=RIDGE)
            leftFrame.pack(side=LEFT)

            leftFrame1 = Frame(topFrame2, bd=5, width=650, height=562, padx=2, bg="gainsboro", relief=RIDGE)
            leftFrame1.pack(side=RIGHT)

            #Creation of text entry fields
            txt = Text(leftFrame1, bd=4, font=('arial', 10,'bold'), width=91, height=32, padx=6, pady=2, wrap=WORD)
            txt.grid(row=1, column=0)
            txt.configure(state=tk.DISABLED)

            txt1 = Text(leftFrame, bd=4, font=('arial', 10,'bold'), width=91, height=23, padx=6, pady=2, wrap=WORD)
            txt1.grid(row=1, column=0)
            txt1.configure(state=tk.DISABLED)
            txt2 = Text(leftFrame, bd=7, font=('arial', 10,'bold'), width=91, height=6.49, padx=6, pady=2, wrap=WORD)
            txt2.grid(row=3, column=0)
            txt2.configure(state=tk.DISABLED)

            #creation of labels 
            self.label = Label(leftFrame, bg='gainsboro', font=('arial',14,'bold'), padx=6,pady=2,text="Webcam screen")
            self.label.grid(row=0, column=0)
            self.label2 = Label(leftFrame, bg='gainsboro', font=('arial',14,'bold'), padx=6,pady=2,text="Sentence formation screen")
            self.label2.grid(row=2, column=0)
            self.label1 = Label(leftFrame1, bg='gainsboro', font=('arial',14,'bold'), padx=6,pady=2,text="Display screen")
            self.label1.grid(row=0, column=0)
            
            #declaration and initialization of string values 
            words1 = StringVar()
            words4 = StringVar()
            words5 = StringVar()
            words6 = StringVar() 

            #creation of server connection
            alias = user_name

            client = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
            client.connect(('127.0.0.1', 59000))

            #defining function client_receive which recieve queries from server
            def client_receive():
                while True:
                    try:
                        message = client.recv(1024).decode('utf-8')
                        if message == "alias?":
                            client.send(alias.encode('utf-8'))
                        else:
                            words1.set(message)
                            txt.configure(state=tk.NORMAL)
                            txt.insert(END, words1.get()+"\n")
                            txt.configure(state=tk.DISABLED)
                            print(message)
                    except:
                        print('Error!')
                        client.close()
                        break

            #creation of function which recieve queries from server
            receive_thread = threading.Thread(target=client_receive)
            receive_thread.start()

            # =====================================================================================================
            #defining client_sends function to sent message to another client
            def client_sends():
                txt.configure(state=tk.NORMAL)
                words4.set(str(txt2.get('1.0', END)))

                if len(txt2.get("1.0", END)) == 1 & len(txt2.get("1.0", END)) == len(words4.get()):
                    print("fffffffffff")
                    client_sends = tkinter.messagebox.showwarning("SIGNING SCREEN", "Sentence formation screen is empty")
                    return

                #creation of client_send function
                def client_send():
                    message = f'{alias}: {words4.get()}'
                    client.send(message.encode('utf-8'))
                    txt2.configure(state=tk.NORMAL)
                    words5.set(str(txt2.get('1.0', END)))

                    txt2.configure(state=tk.NORMAL)
                    txt2.delete("1.0",END)
                    txt2.configure(state=tk.DISABLED)

                #creation of client_send function
                send_thread = threading.Thread(target=client_send)
                send_thread.start()
                txt.configure(state=tk.DISABLED)

            #defining Recognition function for facial expression detection
            def Recognition(): 
                #declarion and initialization of seconds for timing
                seconds = 20
                seconds1 = 20
                seconds2 = 20
                seconds3 = 20
                seconds4 = 20
                
                #opencv fuction to open webcam for detection
                cap = cv2.VideoCapture(0)
                #creation mediapipe holistic model for detections 
                while cap.isOpened():
                    #initiate holistic model
                    ret, frame = cap.read()
                    #recolor feed
                    # Check if frame is not read properly then continue to the next iteration to read the next frame.
                    if not ret:
                        continue
                    image = cv2.cvtColor(frame, 1)
                    #image = cv2.flip(frame, 1)
                    #image = cv2.cvtColor(frame, cv2.COLOR_RGB2BGR)
                    image.flags.writeable = False
                    #Make Detection
                    results = holistic.process(image)
                    #print(results.face_landmarks)
                    #face_landmarks, pose_landmarks, left_hand_landmarks, right_hand_landmarks
                    #Recolor feed
                    image.flags.writeable = True
                    image = cv2.cvtColor(frame, 1)

                    cv2.rectangle(image, (190, 100), (460, 420), (0, 255, 0))
                    #Export coordinates
                    try:
                        #Extract pose landmarks
                        pose = results.pose_landmarks.landmark
                        pose_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in pose]).flatten())

                        #Extract face landmarrks
                        face = results.face_landmarks.landmark
                        face_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in face]).flatten())

                        #concatenate rows
                        row = pose_row+face_row
                            
                        #make detection
                        x = pd.DataFrame([row])
                        body_language_class = model1.predict(x)[0]
                        body_language_prob = model1.predict_proba(x)[0]

                        #grab ear coords
                        coords = tuple(np.multiply(np.array((results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].x,
                                                            results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].y,))
                                                       , [640, 480]).astype(int))

                        cv2.rectangle(image, 
                                        (coords[0], coords[1]+5),
                                        (coords[0]+len(body_language_class)*20, coords[1]-30),
                                        (245, 117, 16), -1)

                        cv2.putText(image, body_language_class, coords,
                                       cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
                        #Initializing namess with detected values
                        namess = body_language_class
                        #test and time detected values
                        if namess == "Normal":
                            txt2.configure(state=tk.NORMAL)
                            valuess = "W"
                            seconds1 = 20
                            seconds2 = 20
                            if valuess == "W":
                                    
                                seconds-=1
                                cv2.putText(image, f'Timing: {int(seconds)}', (0, 350), cv2.FONT_HERSHEY_COMPLEX, 1, (200, 200, 200), 2)
                                    
                                if seconds == 1:
                                    txt2.insert(END, "Normal ")
                                    seconds = 20
                            txt2.configure(state=tk.DISABLED)
                        if namess == "Happy":
                            txt2.configure(state=tk.NORMAL)
                            valuess = "W"
                            seconds = 20
                            seconds2 = 20
                            if valuess == "W":
                                    
                                seconds1-=1
                                cv2.putText(image, f'Timing: {int(seconds1)}', (0, 350), cv2.FONT_HERSHEY_COMPLEX, 1, (200, 200, 200), 2)
                                    
                                if seconds1 == 1:
                                    txt2.insert(END, "Happy ")
                                    seconds1 = 20
                            txt2.configure(state=tk.DISABLED)
                        if namess == "Sad":
                            txt2.configure(state=tk.NORMAL)
                            valuess = "W"
                            seconds = 20
                            seconds1 = 20
                            if valuess == "W":
                                    
                                seconds2-=1
                                cv2.putText(image, f'Timing: {int(seconds2)}', (0, 350), cv2.FONT_HERSHEY_COMPLEX, 1, (200, 200, 200), 2)
                                    
                                if seconds2 == 1:
                                    txt2.insert(END, "Sad ")
                                    seconds2 = 20
                            txt2.configure(state=tk.DISABLED)
                    except:
                        pass

                    #creation of opencv imshow function to show detections and everything to be desplayed on webcam
                    cv2.imshow('Raw Webcam Feed', image)
                    #terminate or destroy webcam
                    if cv2.waitKey(10) & 0xFF == ord('q'):
                        break
                #release webcam
                cap.release()
                #destroy webcam
                cv2.destroyAllWindows()
                #creation of move fuction to remove duplicates
                move()
                #creation of talks function to output speech 
                talks()
            #defining Recognition function for facial expression detection
            def FRecognition(): 
                #declarion and initialization of seconds for timing
                seconds = 20
                seconds1 = 20
                seconds2 = 20
                seconds3 = 20
                seconds4 = 20
                
                #opencv fuction to open webcam for detection
                cap = cv2.VideoCapture(0)
                #creation mediapipe holistic model for detections 
                while cap.isOpened():
                    #initiate holistic model
                    ret, frame = cap.read()
                    #recolor feed
                    # Check if frame is not read properly then continue to the next iteration to read the next frame.
                    if not ret:
                        continue
                    image = cv2.cvtColor(frame, 1)
                    #image = cv2.flip(frame, 1)
                    #image = cv2.cvtColor(frame, cv2.COLOR_RGB2BGR)
                    image.flags.writeable = False
                    #Make Detection
                    results = holistic.process(image)
                    #print(results.face_landmarks)
                    #face_landmarks, pose_landmarks, left_hand_landmarks, right_hand_landmarks
                    #Recolor feed
                    image.flags.writeable = True
                    image = cv2.cvtColor(frame, 1)

                    cv2.rectangle(image, (190, 100), (460, 420), (0, 255, 0))
                    #Export coordinates
                    try:
                        #Extract pose landmarks
                        pose = results.pose_landmarks.landmark
                        pose_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in pose]).flatten())

                        #Extract face landmarrks
                        face = results.face_landmarks.landmark
                        face_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in face]).flatten())

                        #concatenate rows
                        row = pose_row+face_row
                            
                        #make detection
                        x = pd.DataFrame([row])
                        body_language_class = model.predict(x)[0]
                        body_language_prob = model.predict_proba(x)[0]

                        #grab ear coords
                        coords = tuple(np.multiply(np.array((results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].x,
                                                            results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].y,))
                                                       , [640, 480]).astype(int))

                        cv2.rectangle(image, 
                                        (coords[0], coords[1]+5),
                                        (coords[0]+len(body_language_class)*20, coords[1]-30),
                                        (245, 117, 16), -1)

                        cv2.putText(image, body_language_class, coords,
                                       cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
                        #Initializing namess with detected values
                        namess = body_language_class
                        #test and time detected values
                        if namess == "Normal":
                            txt2.configure(state=tk.NORMAL)
                            valuess = "W"
                            seconds1 = 20
                            seconds2 = 20
                            if valuess == "W":
                                    
                                seconds-=1
                                cv2.putText(image, f'Timing: {int(seconds)}', (0, 350), cv2.FONT_HERSHEY_COMPLEX, 1, (200, 200, 200), 2)
                                    
                                if seconds == 1:
                                    txt2.insert(END, "Normal ")
                                    seconds = 20
                            txt2.configure(state=tk.DISABLED)
                        if namess == "Happy":
                            txt2.configure(state=tk.NORMAL)
                            valuess = "W"
                            seconds = 20
                            seconds2 = 20
                            if valuess == "W":
                                    
                                seconds1-=1
                                cv2.putText(image, f'Timing: {int(seconds1)}', (0, 350), cv2.FONT_HERSHEY_COMPLEX, 1, (200, 200, 200), 2)
                                    
                                if seconds1 == 1:
                                    txt2.insert(END, "Happy ")
                                    seconds1 = 20
                            txt2.configure(state=tk.DISABLED)
                        if namess == "Sad":
                            txt2.configure(state=tk.NORMAL)
                            valuess = "W"
                            seconds = 20
                            seconds1 = 20
                            if valuess == "W":
                                    
                                seconds2-=1
                                cv2.putText(image, f'Timing: {int(seconds2)}', (0, 350), cv2.FONT_HERSHEY_COMPLEX, 1, (200, 200, 200), 2)
                                    
                                if seconds2 == 1:
                                    txt2.insert(END, "Sad ")
                                    seconds2 = 20
                            txt2.configure(state=tk.DISABLED)
                    except:
                        pass

                    #creation of opencv imshow function to show detections and everything to be desplayed on webcam
                    cv2.imshow('Raw Webcam Feed', image)
                    #terminate or destroy webcam
                    if cv2.waitKey(10) & 0xFF == ord('q'):
                        break
                #release webcam
                cap.release()
                #destroy webcam
                cv2.destroyAllWindows()
                #creation of move fuction to remove duplicates
                move()
                #creation of talks function to output speech 
                talks()
            #defining move function to remove duplecates
            def move():
                family_list = []
                input_string = StringVar()

                input_string.set(str(txt2.get('1.0', END)))


                family_list = input_string.get().split(" ")
                print(family_list)

                txt2.configure(state=tk.NORMAL)
                txt2.delete("1.0",END)
                txt2.configure(state=tk.DISABLED)

                def removeAllConsecutive(frfg):
                    result = []
                    for (key,group) in groupby(family_list):
                         result.append(key)
                    txt2.configure(state=tk.NORMAL)
                    txt2.insert(END, ' '.join(result))
                    txt2.configure(state=tk.DISABLED)
                removeAllConsecutive(family_list)
            #defining talks function
            def talks():
                txt2.configure(state=tk.NORMAL)
                words5.set(str(txt2.get('1.0', END)))
                engine=pyttsx3.init()
                engine.say(words5.get())
                engine.setProperty('rate', 150)
                rate = engine.getProperty('rate')# getting details of current speaking rate
                

                engine.runAndWait()
                txt2.configure(state=tk.DISABLED)

            #defining homes function
            def homes():
                self.root.destroy()
                print("Helloqw")
                Home(user_name)

            #defining exit function
            def Exit():
                Exit = tkinter.messagebox.askyesno("SIGNING SCREEN", "confirm if you want to exit")
                if Exit>0:
                    self.root.destroy()
                    return
            #defining Choose function to choose wheather you want to use hand gesture or facial expressions
            def Choose():
                #creation of Recognition function
                Recognition()
            def FChoose():
                #creation of Recognition function
                FRecognition()
            #=======================================================================================================
            #creation of Activate button to call Choose function
            self.btnActivate = Button(topFrame, pady=1, bd=4, fg="black", font=('arial',16,'bold'), padx=24,
                                         width=10, command= FChoose, text="Facial Expression").grid(row=0, column=1, padx=1)

            #creation of Home button to call homes function which will help to navigate back to Home screen
            self.btnHome = Button(topFrame, pady=1, bd=4, fg="black", font=('arial', 16, 'bold'), padx=24,
                                         width=10, command=homes, text="Home").grid(row=0, column=0, padx=1)

            #creation of Exit button to call exit function
            self.btnExit = Button(topFrame, pady=1, bd=4, fg="black", font=('arial', 16, 'bold'), padx=24,
                                   width=10, command = Choose, text="Face Recognition").grid(row=0, column=2, padx=1)
            
            self.btnExit = Button(topFrame, pady=1, bd=4, fg="black", font=('arial', 16, 'bold'), padx=24,
                                   width=10, command = Exit, text="Exit").grid(row=0, column=3, padx=1)

            #creation of Send Response button to call client_sends function
            self.btnResponse = Button(topFrame1, pady=1, bd=4, fg="black", font=('arial', 16, 'bold'), padx=24,
                                  width=20, command = client_sends, text="Send").grid(row=0, column=0, padx=1)
            #mainloop of python GUI
            self.root.mainloop()
            #=======================================================================================================
            
            #=======================================================================================================
            #=======================================================================================================
    except:
        pass
#Creation of TypingDisplay class 
class TypingDisplay:
    #try fuction to handle errors
    try:
        def __init__(self, user_name):
            #creation of python GUI
            self.root = Tk()
            self.root.title("HAND RECOGNITION SCREEN")
            self.root.geometry("13660x800+0+0")
            self.root.configure(bg='gainsboro')

            #creation of GUI frames
            mainFrame = Frame(self.root, bd=10, width=1350, height=700, relief=RIDGE)
            mainFrame.grid()
            mainFrame.place(rely = 0.5, relx = 0.5, anchor=CENTER)

            topFrame = Frame(mainFrame, bd=5, width=1340, height=50, relief=RIDGE)
            topFrame.grid(row=0, column=0)

            topFrame1 = Frame(mainFrame, bd=5, width=1340, height=45, relief=RIDGE)
            topFrame1.grid(row=2, column=0)

            topFrame2 = Frame(mainFrame, bd=5, width=1340, height=495, relief=RIDGE)
            topFrame2.grid(row=1, column=0)

            leftFrame = Frame(topFrame2, bd=5, width=650, height=562, padx=2, bg="gainsboro", relief=RIDGE)
            leftFrame.pack(side=LEFT)

            leftFrame1 = Frame(topFrame2, bd=5, width=650, height=562, padx=2, bg="gainsboro", relief=RIDGE)
            leftFrame1.pack(side=RIGHT)

            #Creation of text entry fields
            txt = Text(leftFrame1, bd=4, font=('arial', 10,'bold'), width=91, height=32, padx=6, pady=2, wrap=WORD)
            txt.grid(row=1, column=0)
            txt.configure(state=tk.DISABLED)

            txt1 = Text(leftFrame, bd=4, font=('arial', 10,'bold'), width=91, height=23, padx=6, pady=2, wrap=WORD)
            txt1.grid(row=1, column=0)
            txt1.configure(state=tk.DISABLED)
            txt2 = Text(leftFrame, bd=7, font=('arial', 10,'bold'), width=91, height=6.49, padx=6, pady=2, wrap=WORD)
            txt2.grid(row=3, column=0)
            txt2.configure(state=tk.DISABLED)

            #creation of labels 
            self.label = Label(leftFrame, bg='gainsboro', font=('arial',14,'bold'), padx=6,pady=2,text="Webcam screen")
            self.label.grid(row=0, column=0)
            self.label2 = Label(leftFrame, bg='gainsboro', font=('arial',14,'bold'), padx=6,pady=2,text="Sentence formation screen")
            self.label2.grid(row=2, column=0)
            self.label1 = Label(leftFrame1, bg='gainsboro', font=('arial',14,'bold'), padx=6,pady=2,text="Display screen")
            self.label1.grid(row=0, column=0)
            
            #declaration and initialization of string values 
            words1 = StringVar()
            words4 = StringVar()
            words5 = StringVar()
            words6 = StringVar() 

            #creation of server connection
            alias = user_name

            client = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
            client.connect(('127.0.0.1', 59000))

            #defining function client_receive which recieve queries from server
            def client_receive():
                while True:
                    try:
                        message = client.recv(1024).decode('utf-8')
                        if message == "alias?":
                            client.send(alias.encode('utf-8'))
                        else:
                            words1.set(message)
                            txt.configure(state=tk.NORMAL)
                            txt.insert(END, words1.get()+"\n")
                            txt.configure(state=tk.DISABLED)
                            print(message)
                    except:
                        print('Error!')
                        client.close()
                        break

            #creation of function which recieve queries from server
            receive_thread = threading.Thread(target=client_receive)
            receive_thread.start()

            # =====================================================================================================
            #Defining fuction for hand gesture detections
            def Hands():
                #declaration and initializatio of volume pecentages fomular 
                volPec = 0
                volPec1 = 0
                volPec2 = 0
                volPec3 = 0
                volPec4 = 0
                volPec5 = 0
                volPec6 = 0
                volPec7 = 0
                volPec8 = 0
                volPec9 = 0
                volPec10 = 0
                volPec11 = 0
                volPec12 = 0
                volPec13 = 0
                volPec14 = 0
                volPec15 = 0
                
                #set the size of wencam frame(screen)
                wCam, hCam = 350, 500
                
                #opencv fuction to open webcam for detection
                cap = cv2.VideoCapture(0)
                cap.set(5, wCam)
                cap.set(6, hCam)

                words7 = StringVar()

                #creation of timing
                pTime = 0

                #calling handTraking class in handTrackingModule
                detector = htm.handDetector(detectionCon = 0.8)
                
                #creation of mediapipe handlandkarks tips
                tipIds = [4, 8, 12, 16, 20]
                
                #decalration and initialization of seconds timing
                seconds = 50
                seconds1 = 50
                seconds2 = 50
                seconds3 = 50
                seconds4 = 50
                seconds5 = 50
                seconds6 = 35
                seconds7 = 50
                seconds8 = 50
                seconds9 = 50
                seconds10 = 50
                seconds11 = 50
                seconds12 = 50
                seconds13 = 50
                seconds14 = 50
                seconds15 = 50
                seconds16 = 50
                seconds17 = 50
                seconds18 = 50
                seconds19 = 50
                seconds20 = 50
                seconds21 = 50
                seconds22 = 50
                seconds23 = 50
                seconds24 = 35
                seconds25 = 50
                seconds26 = 50
                
                #creation of while loop
                while True:
                    #declaration of img and success to webcam
                    success, img = cap.read()

                    #initializing wencam to handTrackingModule
                    img = detector.findHands(img)
                    #initialization of lmlIst to hand positions fro handTrackingModule
                    lmList = detector.findPosition(img, draw=False)
                    #print(lmList)

                    #test wheather hand is detected or not
                    if len(lmList) != 0:
                        #put each finger tips into x and y
                        x1, y1 = lmList[4][1], lmList[4][2]

                        x2, y2 = lmList[8][1], lmList[8][2]
                        x11, y11 = lmList[5][1], lmList[5][2]
                        x12, y12 = lmList[6][1], lmList[6][2]
                        x13, y13 = lmList[7][1], lmList[7][2]

                        x3, y3 = lmList[12][1], lmList[12][2]
                        x31, y31 = lmList[11][1], lmList[11][2]
                        x32, y32 = lmList[10][1], lmList[10][2]
                        x33, y33 = lmList[9][1], lmList[9][2]

                        x4, y4 = lmList[16][1], lmList[16][2]
                        x41, y41 = lmList[15][1], lmList[15][2]
                        x42, y42 = lmList[14][1], lmList[14][2]
                        x43, y43 = lmList[13][1], lmList[13][2]

                        x5, y5 = lmList[20][1], lmList[20][2]
                        x51, y51 = lmList[19][1], lmList[19][2]
                        x52, y52 = lmList[18][1], lmList[18][2]
                        x53, y53 = lmList[17][1], lmList[17][2]

                        #creation for angles and length calculations
                        cx, cy = (x1 + x2) // 2, (y1 + y2) //2
                        cx1, cy1 = (x1 + x11) // 2, (y1 + y11) //2
                        cx12, cy12 = (x1 + x12) // 2, (y1 + y12) //2
                        cx13, cy13 = (x1 + x13) // 2, (y1 + y13) //2

                        cx0, cy0 = (x2 + x3) // 2, (y2 + y3) //2
                        cx01, cy01 = (x2 + x31) // 2, (y2 + y31) //2
                        cx012, cy012 = (x2 + x32) // 2, (y2 + y32) //2

                        cx3, cy3 = (x1 + x3) // 2, (y1 + y3) //2
                        cx31, cy31 = (x1 + x31) // 2, (y1 + y31) //2
                        cx32, cy32 = (x1 + x32) // 2, (y1 + y32) //2
                        cx33, cy33 = (x1 + x33) // 2, (y1 + y33) //2

                        cx4, cy4 = (x1 + x4) // 2, (y1 + y4) //2
                        cx41, cy41 = (x1 + x41) // 2, (y1 + y41) //2
                        cx42, cy42 = (x1 + x42) // 2, (y1 + y42) //2
                        cx43, cy43 = (x1 + x43) // 2, (y1 + y43) //2

                        cx5, cy5 = (x1 + x5) // 2, (y1 + y5) //2
                        cx51, cy51 = (x1 + x51) // 2, (y1 + y51) //2
                        cx52, cy52 = (x1 + x52) // 2, (y1 + y52) //2
                        cx53, cy53 = (x1 + x53) // 2, (y1 + y53) //2
                        #cx1, cy1 = ()

                        #drawing hand finger's linkage lines for angles and lengths 
                        cv2.circle(img, (x1, y1), None, (255, 255, 255), cv2.FILLED)
                        cv2.circle(img, (x2, y2), None, (255, 255, 255), cv2.FILLED)
                        cv2.circle(img, (cx, cy), None, (255, 255, 255), cv2.FILLED)
                        cv2.line(img, (x1, y1), (x2, y2), (255, 255, 255), None)

                        cv2.circle(img, (x2, y2), None, (0, 255, 255), cv2.FILLED)
                        cv2.circle(img, (x3, y3), None, (255, 255, 255), cv2.FILLED)
                        cv2.circle(img, (cx0, cy0), None, (255, 255, 255), cv2.FILLED)
                        cv2.line(img, (x2, y2), (x3, y3), (255, 255, 255), None)

                        cv2.circle(img, (x2, y2), None, (0, 255, 255), cv2.FILLED)
                        cv2.circle(img, (x31, y31), None, (255, 255, 255), cv2.FILLED)
                        cv2.circle(img, (cx01, cy01), None, (255, 255, 255), cv2.FILLED)
                        cv2.line(img, (x2, y2), (x31, y31), (255, 255, 255), None)

                        cv2.circle(img, (x2, y2), None, (0, 255, 255), cv2.FILLED)
                        cv2.circle(img, (x32, y32), None, (255, 255, 255), cv2.FILLED)
                        cv2.circle(img, (cx012, cy012), None, (255, 255, 255), cv2.FILLED)
                        cv2.line(img, (x2, y2), (x32, y32), (255, 255, 255), None)

                        cv2.circle(img, (x1, y1), None, (255, 255, 255), cv2.FILLED)
                        cv2.circle(img, (x11, y11), None, (255, 255, 255), cv2.FILLED)
                        cv2.circle(img, (cx1, cy1), None, (255, 255, 255), cv2.FILLED)
                        cv2.line(img, (x1, y1), (x11, y11), (255, 255, 255), None)

                        cv2.circle(img, (x1, y1), None, (255, 255, 255), cv2.FILLED)
                        cv2.circle(img, (x12, y12), None, (255, 255, 255), cv2.FILLED)
                        cv2.circle(img, (cx12, cy12), None, (255, 255, 255), cv2.FILLED)
                        cv2.line(img, (x1, y1), (x12, y12), (255, 255, 255), None)

                        cv2.circle(img, (x1, y1), None, (255, 255, 255), cv2.FILLED)
                        cv2.circle(img, (x13, y13), None, (255, 255, 255), cv2.FILLED)
                        cv2.circle(img, (cx13, cy13), None, (255, 255, 255), cv2.FILLED)
                        cv2.line(img, (x1, y1), (x13, y13), (255, 255, 255), None)

                        cv2.circle(img, (x1, y1), None, (255, 255, 255), cv2.FILLED)
                        cv2.circle(img, (x3, y3), None, (255, 255, 255), cv2.FILLED)
                        cv2.circle(img, (cx3, cy3), None, (255, 255, 255), cv2.FILLED)
                        cv2.line(img, (x1, y1), (x3, y3), (255, 255, 255), None)

                        cv2.circle(img, (x1, y1), None, (255, 255, 255), cv2.FILLED)
                        cv2.circle(img, (x31, y31), None, (255, 255, 255), cv2.FILLED)
                        cv2.circle(img, (cx31, cy31), None, (255, 255, 255), cv2.FILLED)
                        cv2.line(img, (x1, y1), (x31, y31), (255, 255, 255), None)

                        cv2.circle(img, (x1, y1), None, (255, 255, 255), cv2.FILLED)
                        cv2.circle(img, (x32, y32), None, (255, 255, 255), cv2.FILLED)
                        cv2.circle(img, (cx32, cy32), None, (255, 255, 255), cv2.FILLED)
                        cv2.line(img, (x1, y1), (x32, y32), (255, 255, 255), None)

                        cv2.circle(img, (x1, y1), None, (255, 255, 255), cv2.FILLED)
                        cv2.circle(img, (x33, y33), None, (255, 255, 255), cv2.FILLED)
                        cv2.circle(img, (cx33, cy33), None, (255, 255, 255), cv2.FILLED)
                        cv2.line(img, (x1, y1), (x33, y33), (255, 255, 255), None)

                        cv2.circle(img, (x1, y1), None, (255, 255, 255), cv2.FILLED)
                        cv2.circle(img, (x4, y4), None, (255, 255, 255), cv2.FILLED)
                        cv2.circle(img, (cx4, cy4), None, (255, 255, 255), cv2.FILLED)
                        cv2.line(img, (x1, y1), (x4, y4), (255, 255, 255), None)

                        cv2.circle(img, (x1, y1), None, (255, 255, 255), cv2.FILLED)
                        cv2.circle(img, (x41, y41), None, (255, 255, 255), cv2.FILLED)
                        cv2.circle(img, (cx41, cy41), None, (255, 255, 255), cv2.FILLED)
                        cv2.line(img, (x1, y1), (x41, y41), (255, 255, 255), None)

                        cv2.circle(img, (x1, y1), None, (255, 255, 255), cv2.FILLED)
                        cv2.circle(img, (x42, y42), None, (255, 255, 255), cv2.FILLED)
                        cv2.circle(img, (cx42, cy42), None, (255, 255, 255), cv2.FILLED)
                        cv2.line(img, (x1, y1), (x42, y42), (255, 255, 255), None)

                        cv2.circle(img, (x1, y1), None, (255, 255, 255), cv2.FILLED)
                        cv2.circle(img, (x43, y43), None, (255, 255, 255), cv2.FILLED)
                        cv2.circle(img, (cx43, cy43), None, (255, 255, 255), cv2.FILLED)
                        cv2.line(img, (x1, y1), (x43, y43), (255, 255, 255), None)

                        cv2.circle(img, (x1, y1), None, (255, 255, 255), cv2.FILLED)
                        cv2.circle(img, (x5, y5), None, (255, 255, 255), cv2.FILLED)
                        cv2.circle(img, (cx5, cy5), None, (255, 255, 255), cv2.FILLED)
                        cv2.line(img, (x1, y1), (x5, y5), (255, 255, 255), None)

                        cv2.circle(img, (x1, y1), None, (255, 255, 255), cv2.FILLED)
                        cv2.circle(img, (x51, y51), None, (255, 255, 255), cv2.FILLED)
                        cv2.circle(img, (cx51, cy51), None, (255, 255, 255), cv2.FILLED)
                        cv2.line(img, (x1, y1), (x51, y51), (255, 255, 255), None)

                        cv2.circle(img, (x1, y1), None, (255, 255, 255), cv2.FILLED)
                        cv2.circle(img, (x52, y52), None, (255, 255, 255), cv2.FILLED)
                        cv2.circle(img, (cx52, cy52), None, (255, 255, 255), cv2.FILLED)
                        cv2.line(img, (x1, y1), (x52, y52), (255, 255, 255), None)

                        cv2.circle(img, (x1, y1), None, (255, 255, 255), cv2.FILLED)
                        cv2.circle(img, (x53, y53), None, (255, 255, 255), cv2.FILLED)
                        cv2.circle(img, (cx53, cy53), None, (255, 255, 255), cv2.FILLED)
                        cv2.line(img, (x1, y1), (x53, y53), (255, 255, 255), None)

                        #creation of length calculation formulars
                        length = math.hypot(x2-x1, y2-y1)
                        length16 = math.hypot(x3-x2, y3-y2)
                        length17 = math.hypot(x31-x2, y31-y2)
                        length18 = math.hypot(x32-x2, y32-y2)
                        length1 = math.hypot(x11-x1, y11-y1)
                        length2 = math.hypot(x12-x1, y12-y1)
                        length3 = math.hypot(x13-x1, y13-y1)

                        length4 = math.hypot(x3-x1, y3-y1)
                        length5 = math.hypot(x31-x1, y31-y1)
                        length6 = math.hypot(x32-x1, y32-y1)
                        length7 = math.hypot(x33-x1, y33-y1)

                        length8 = math.hypot(x4-x1, y4-y1)
                        length9 = math.hypot(x41-x1, y41-y1)
                        length10 = math.hypot(x42-x1, y42-y1)
                        length11 = math.hypot(x43-x1, y43-y1)

                        length12 = math.hypot(x5-x1, y5-y1)
                        length13 = math.hypot(x51-x1, y51-y1)
                        length14 = math.hypot(x52-x1, y52-y1)
                        length15 = math.hypot(x53-x1, y53-y1)

                        #initialization of volume percentages with lengths and put length interpretaions in them
                        volPec = np.interp(length, [50, 300], [0, 100])
                        volPec1 = np.interp(length1, [50, 300], [0, 100])
                        volPec2 = np.interp(length2, [50, 300], [0, 100])
                        volPec3 = np.interp(length3, [50, 300], [0, 100])
                        volPec4 = np.interp(length4, [50, 300], [0, 100])
                        volPec5 = np.interp(length5, [50, 300], [0, 100])
                        volPec6 = np.interp(length6, [50, 300], [0, 100])
                        volPec8 = np.interp(length8, [50, 300], [0, 100])
                        volPec7 = np.interp(length7, [50, 300], [0, 100])
                        volPec9 = np.interp(length9, [50, 300], [0, 100])
                        volPec10 = np.interp(length10, [50, 300], [0, 100])
                        volPec11 = np.interp(length11, [50, 300], [0, 100])
                        volPec12 = np.interp(length12, [50, 300], [0, 100])
                        volPec13 = np.interp(length13, [50, 300], [0, 100])
                        volPec14 = np.interp(length14, [50, 300], [0, 100])
                        volPec15 = np.interp(length15, [50, 300], [0, 100])

                        volPec16 = 0
                        volPec17 = 0
                        volPec18 = 0

                        volPec16 = np.interp(length16, [50, 300], [0, 100])
                        volPec17 = np.interp(length17, [50, 300], [0, 100])
                        volPec18 = np.interp(length18, [50, 300], [0, 100])
                        #volPec16 = np.interp(length16, [50, 300], [0, 100])
                        
                        #try fuction to handle unexpected errors (this was useful for robustness of system)
                        try:
                            #test webcam detection sign language hand gestures with our fomulars
                            if (volPec>25) and (volPec4>20 and volPec4<35) and (volPec8>25) and (volPec12>30):
                                cv2.rectangle(img, (20, 190), (140, 300), (0, 255, 0), cv2.FILLED)
                                cv2.putText(img, "C", (45, 280), cv2.FONT_HERSHEY_PLAIN, 5, (255, 0, 0), 5)
                                txt2.configure(state=tk.NORMAL)
                                seconds1 = 50
                                seconds2 = 50
                                seconds3 = 50
                                seconds4 = 50
                                seconds5 = 50
                                seconds6 = 35
                                seconds7 = 50
                                seconds8 = 50
                                seconds9 = 50
                                seconds10 = 50
                                seconds11 = 50
                                seconds12 = 50
                                seconds13 = 50
                                seconds14 = 50
                                seconds15 = 50
                                seconds16 = 50
                                seconds17 = 50
                                seconds18 = 50
                                seconds19 = 50
                                seconds20 = 50
                                seconds21 = 50
                                seconds22 = 50
                                seconds23 = 50
                                seconds24 = 35
                                seconds25 = 50
                                seconds26 = 50
                                
                                valuess = "c"
                                
                                if valuess == "c":
                                    seconds-=1
                                    cv2.putText(img, f'Timing: {int(seconds)}', (0, 350), cv2.FONT_HERSHEY_COMPLEX, 1, (200, 200, 200), 2)
                                    
                                    if seconds == 1:
                                        txt2.insert(END, "C")
                                        seconds = 50
                                txt2.configure(state=tk.DISABLED)
                            if volPec13<5 and volPec9<5 and volPec8<5 and volPec4<5:
                                cv2.rectangle(img, (20, 190), (140, 300), (0, 255, 0), cv2.FILLED)
                                cv2.putText(img, "E", (45, 280), cv2.FONT_HERSHEY_PLAIN, 5, (255, 0, 0), 5)
                                txt2.configure(state=tk.NORMAL)
                                seconds = 50
                                seconds2 = 50
                                seconds3 = 50
                                seconds4 = 50
                                seconds5 = 50
                                seconds6 = 35
                                seconds7 = 50
                                seconds8 = 50
                                seconds9 = 50
                                seconds10 = 50
                                seconds11 = 50
                                seconds12 = 50
                                seconds13 = 50
                                seconds14 = 50
                                seconds15 = 50
                                seconds16 = 50
                                seconds17 = 50
                                seconds18 = 50
                                seconds19 = 50
                                seconds20 = 50
                                seconds21 = 50
                                seconds22 = 50
                                seconds23 = 50
                                seconds24 = 35
                                seconds25 = 50
                                seconds26 = 50
                                valuess = "E"
                                
                                if valuess == "E":
                                    seconds1-=1
                                    cv2.putText(img, f'Timing: {int(seconds1)}', (0, 350), cv2.FONT_HERSHEY_COMPLEX, 1, (200, 200, 200), 2)
                                    
                                    if seconds1 == 1:
                                        txt2.insert(END, "E")
                                        seconds1 = 50
                                txt2.configure(state=tk.DISABLED)
                            if (lmList[20][2]<lmList[18][2]) and (volPec<3) and volPec4<3 and (volPec8>0 and volPec8<20) and (volPec12>20):
                                cv2.rectangle(img, (20, 190), (140, 300), (0, 255, 0), cv2.FILLED)
                                cv2.putText(img, "O", (45, 280), cv2.FONT_HERSHEY_PLAIN, 5, (255, 0, 0), 5)
                                txt2.configure(state=tk.NORMAL)
                                seconds = 50
                                seconds1 = 50
                                seconds3 = 50
                                seconds4 = 50
                                seconds5 = 50
                                seconds6 = 35
                                seconds7 = 50
                                seconds8 = 50
                                seconds9 = 50
                                seconds10 = 50
                                seconds11 = 50
                                seconds12 = 50
                                seconds13 = 50
                                seconds14 = 50
                                seconds15 = 50
                                seconds16 = 50
                                seconds17 = 50
                                seconds18 = 50
                                seconds19 = 50
                                seconds20 = 50
                                seconds21 = 50
                                seconds22 = 50
                                seconds23 = 50
                                seconds24 = 35
                                seconds25 = 50
                                seconds26 = 50
                                valuess = "O"
                                
                                if valuess == "O":
                                    seconds2-=1
                                    cv2.putText(img, f'Timing: {int(seconds2)}', (0, 350), cv2.FONT_HERSHEY_COMPLEX, 1, (200, 200, 200), 2)
                                    
                                    if seconds2 == 1:
                                        txt2.insert(END, "O")
                                        seconds2 = 50
                                txt2.configure(state=tk.DISABLED)
                            if (volPec>0 and volPec<20) and (volPec1>0 and volPec1<20) and (volPec2>0 and volPec2<20) and (volPec7>0 and volPec7<20):# and (volPec1>0 and volPec1<4) and (volPec2>0 and volPec2<4) and (volPec3==0 and volPec3<4):
                                cv2.rectangle(img, (20, 190), (140, 300), (0, 255, 0), cv2.FILLED)
                                cv2.putText(img, "Q ", (45, 280), cv2.FONT_HERSHEY_PLAIN, 5, (255, 0, 0), 5)
                                txt2.configure(state=tk.NORMAL)
                                seconds = 50
                                seconds1 = 50
                                seconds2 = 50
                                seconds4 = 50
                                seconds5 = 50
                                seconds6 = 35
                                seconds7 = 50
                                seconds8 = 50
                                seconds9 = 50
                                seconds10 = 50
                                seconds11 = 50
                                seconds12 = 50
                                seconds13 = 50
                                seconds14 = 50
                                seconds15 = 50
                                seconds16 = 50
                                seconds17 = 50
                                seconds18 = 50
                                seconds19 = 50
                                seconds20 = 50
                                seconds21 = 50
                                seconds22 = 50
                                seconds23 = 50
                                seconds24 = 35
                                seconds25 = 50
                                seconds26 = 50
                                valuess = "Q"
                                
                                if valuess == "Q":
                                    seconds3-=1
                                    cv2.putText(img, f'Timing: {int(seconds3)}', (0, 350), cv2.FONT_HERSHEY_COMPLEX, 1, (200, 200, 200), 2)
                                    
                                    if seconds3 == 1:
                                        txt2.insert(END, "Q")
                                        seconds3 = 50
                                txt2.configure(state=tk.DISABLED)
                            if not(lmList[20][2]<lmList[18][2]) and volPec>15 and volPec12>30 and not(lmList[8][2]<lmList[6][2]) and not(lmList[tipIds[0]][1] > lmList[tipIds[0]-1][1]) and not(lmList[12][2]<lmList[10][2]) and not(lmList[16][2]<lmList[14][2]) and not(lmList[20][2]<lmList[18][2]):
                                cv2.rectangle(img, (20, 190), (140, 300), (0, 255, 0), cv2.FILLED)
                                cv2.putText(img, "A", (45, 280), cv2.FONT_HERSHEY_PLAIN, 5, (255, 0, 0), 5)
                                txt2.configure(state=tk.NORMAL)
                                seconds = 50
                                seconds1 = 50
                                seconds2 = 50
                                seconds3 = 50
                                seconds4 = 50
                                seconds5 = 50
                                seconds6 = 35
                                seconds7 = 50
                                seconds8 = 50
                                seconds9 = 50
                                seconds10 = 50
                                seconds11 = 50
                                seconds12 = 50
                                seconds13 = 50
                                seconds14 = 50
                                seconds15 = 50
                                seconds16 = 50
                                seconds17 = 50
                                seconds18 = 50
                                seconds19 = 50
                                seconds20 = 50
                                seconds21 = 50
                                seconds22 = 50
                                seconds23 = 50
                                seconds24 = 35
                                seconds26 = 50
                                valuess = "A"
                                
                                if valuess == "A":
                                    seconds25-=1
                                    cv2.putText(img, f'Timing: {int(seconds25)}', (0, 350), cv2.FONT_HERSHEY_COMPLEX, 1, (200, 200, 200), 2)
                                    print("s")
                                    if seconds25 == 1:
                                        txt2.insert(END, "A")
                                        seconds25 = 50
                                txt2.configure(state=tk.DISABLED)
                            if volPec==0 and (volPec4>15) and volPec12>25 and volPec13>25 and volPec14>25 and not(lmList[8][2]<lmList[6][2]) and not(lmList[tipIds[0]][1] > lmList[tipIds[0]-1][1]) and not(lmList[12][2]<lmList[10][2]) and not(lmList[16][2]<lmList[14][2]) and not(lmList[20][2]<lmList[18][2]):
                                cv2.rectangle(img, (20, 190), (140, 300), (0, 255, 0), cv2.FILLED)
                                cv2.putText(img, "T ", (45, 280), cv2.FONT_HERSHEY_PLAIN, 5, (255, 0, 0), 5)
                                txt2.configure(state=tk.NORMAL)
                                seconds = 50
                                seconds1 = 50
                                seconds2 = 50
                                seconds3 = 50
                                seconds5 = 50
                                seconds6 = 35
                                seconds7 = 50
                                seconds8 = 50
                                seconds9 = 50
                                seconds10 = 50
                                seconds11 = 50
                                seconds12 = 50
                                seconds13 = 50
                                seconds14 = 50
                                seconds15 = 50
                                seconds16 = 50
                                seconds17 = 50
                                seconds18 = 50
                                seconds19 = 50
                                seconds20 = 50
                                seconds21 = 50
                                seconds22 = 50
                                seconds23 = 50
                                seconds24 = 35
                                seconds25 = 50
                                seconds26 = 50
                                valuess = "T"
                                
                                if valuess == "T":
                                    seconds4-=1
                                    cv2.putText(img, f'Timing: {int(seconds4)}', (0, 350), cv2.FONT_HERSHEY_COMPLEX, 1, (200, 200, 200), 2)
                                    
                                    if seconds4 == 1:
                                        txt2.insert(END, "T")
                                        seconds4 = 50
                                txt2.configure(state=tk.DISABLED)
                            if lmList[8][2]<lmList[6][2] and (volPec12>35) and not(lmList[tipIds[0]][1] > lmList[tipIds[0]-1][1]) and (lmList[12][2]<lmList[10][2]) and (lmList[16][2]<lmList[14][2]) and (lmList[20][2]<lmList[18][2]):
                                cv2.rectangle(img, (20, 190), (140, 300), (0, 255, 0), cv2.FILLED)
                                cv2.putText(img, "B", (45, 280), cv2.FONT_HERSHEY_PLAIN, 5, (255, 0, 0), 5)
                                txt2.configure(state=tk.NORMAL)
                                seconds = 50
                                seconds1 = 50
                                seconds2 = 50
                                seconds3 = 50
                                seconds4 = 50
                                seconds6 = 35
                                seconds7 = 50
                                seconds8 = 50
                                seconds9 = 50
                                seconds10 = 50
                                seconds11 = 50
                                seconds12 = 50
                                seconds13 = 50
                                seconds14 = 50
                                seconds15 = 50
                                seconds16 = 50
                                seconds17 = 50
                                seconds18 = 50
                                seconds19 = 50
                                seconds20 = 50
                                seconds21 = 50
                                seconds22 = 50
                                seconds23 = 50
                                seconds24 = 35
                                seconds25 = 50
                                seconds26 = 50
                                valuess = "B"
                                
                                if valuess == "B":
                                    seconds5-=1
                                    cv2.putText(img, f'Timing: {int(seconds5)}', (0, 350), cv2.FONT_HERSHEY_COMPLEX, 1, (200, 200, 200), 2)
                                    
                                    if seconds5 == 1:
                                        txt2.insert(END, "B")
                                        seconds5 = 50
                                txt2.configure(state=tk.DISABLED)
                            if lmList[8][2]<lmList[6][2] and (volPec12>35) and (lmList[tipIds[0]][1] > lmList[tipIds[0]-1][1]) and (lmList[12][2]<lmList[10][2]) and not(lmList[16][2]<lmList[14][2]) and (lmList[20][2]<lmList[18][2]):
                                cv2.putText(img, "space", (45, 280), cv2.FONT_HERSHEY_PLAIN, 5, (255, 0, 0), 5)
                                txt2.configure(state=tk.NORMAL)
                                seconds = 50
                                seconds1 = 50
                                seconds2 = 50
                                seconds3 = 50
                                seconds4 = 50
                                seconds5 = 50
                                seconds7 = 50
                                seconds8 = 50
                                seconds9 = 50
                                seconds10 = 50
                                seconds11 = 50
                                seconds12 = 50
                                seconds13 = 50
                                seconds14 = 50
                                seconds15 = 50
                                seconds16 = 50
                                seconds17 = 50
                                seconds18 = 50
                                seconds19 = 50
                                seconds20 = 50
                                seconds21 = 50
                                seconds22 = 50
                                seconds23 = 50
                                seconds24 = 35
                                seconds25 = 50
                                seconds26 = 50
                                valuess = " "
                                
                                if valuess == " ":
                                    seconds6-=1
                                    cv2.putText(img, f'Timing: {int(seconds6)}', (0, 350), cv2.FONT_HERSHEY_COMPLEX, 1, (200, 200, 200), 2)
                                    
                                    if seconds6 == 1:
                                        txt2.insert(END, " ")
                                        seconds6 = 50
                                txt2.configure(state=tk.DISABLED)
                            if lmList[8][2]<lmList[6][2] and volPec>40 and (lmList[tipIds[0]][1] > lmList[tipIds[0]-1][1]) and not(lmList[12][2]<lmList[10][2]) and (lmList[16][2]<lmList[14][2]) and (lmList[20][2]<lmList[18][2]):
                                cv2.putText(img, "cancel", (45, 280), cv2.FONT_HERSHEY_PLAIN, 5, (0, 0, 255), 5)
                                txt2.configure(state=tk.NORMAL)
                                seconds = 50
                                seconds1 = 50
                                seconds2 = 50
                                seconds3 = 50
                                seconds4 = 50
                                seconds5 = 50
                                seconds6 = 35
                                seconds7 = 50
                                seconds8 = 50
                                seconds9 = 50
                                seconds10 = 50
                                seconds11 = 50
                                seconds12 = 50
                                seconds13 = 50
                                seconds14 = 50
                                seconds15 = 50
                                seconds16 = 50
                                seconds17 = 50
                                seconds18 = 50
                                seconds19 = 50
                                seconds20 = 50
                                seconds21 = 50
                                seconds22 = 50
                                seconds23 = 50
                                seconds25 = 50
                                seconds26 = 50
                                valuess = "ca"
                                
                                if valuess == "ca":
                                    seconds24-=1
                                    cv2.putText(img, f'Timing: {int(seconds24)}', (0, 350), cv2.FONT_HERSHEY_COMPLEX, 1, (200, 200, 200), 2)
                                    
                                    if seconds24 == 1:
                                        cancels()
                                        seconds24 = 35
                                    
                            if lmList[8][2]<lmList[6][2] and volPec16>18 and (volPec17>18) and (volPec18>18) and not(lmList[tipIds[0]][1] > lmList[tipIds[0]-1][1]) and not(lmList[12][2]<lmList[10][2]) and not(lmList[16][2]<lmList[14][2]) and not(lmList[20][2]<lmList[18][2]):
                                cv2.rectangle(img, (20, 190), (140, 300), (0, 255, 0), cv2.FILLED)
                                cv2.putText(img, "D", (45, 280), cv2.FONT_HERSHEY_PLAIN, 5, (255, 0, 0), 5)
                                txt2.configure(state=tk.NORMAL)
                                seconds = 50
                                seconds1 = 50
                                seconds2 = 50
                                seconds3 = 50
                                seconds4 = 50
                                seconds5 = 50
                                seconds6 = 35
                                seconds8 = 50
                                seconds9 = 50
                                seconds10 = 50
                                seconds11 = 50
                                seconds12 = 50
                                seconds13 = 50
                                seconds14 = 50
                                seconds15 = 50
                                seconds16 = 50
                                seconds17 = 50
                                seconds18 = 50
                                seconds19 = 50
                                seconds20 = 50
                                seconds21 = 50
                                seconds22 = 50
                                seconds23 = 50
                                seconds24 = 35
                                seconds25 = 50
                                seconds26 = 50
                                valuess = "D"
                                
                                if valuess == "D":
                                    seconds7-=1
                                    cv2.putText(img, f'Timing: {int(seconds7)}', (0, 350), cv2.FONT_HERSHEY_COMPLEX, 1, (200, 200, 200), 2)
                                    
                                    if seconds7 == 1:
                                        txt2.insert(END, "D")
                                        seconds7 = 50
                                txt2.configure(state=tk.DISABLED)
                            if not(lmList[8][2]<lmList[6][2]) and volPec12>35 and not(lmList[tipIds[0]][1] > lmList[tipIds[0]-1][1]) and (lmList[12][2]<lmList[10][2]) and (lmList[16][2]<lmList[14][2]) and (lmList[20][2]<lmList[18][2]):
                                cv2.rectangle(img, (20, 190), (140, 300), (0, 255, 0), cv2.FILLED)
                                cv2.putText(img, "F", (45, 280), cv2.FONT_HERSHEY_PLAIN, 5, (255, 0, 0), 5)
                                txt2.configure(state=tk.NORMAL)
                                seconds = 50
                                seconds1 = 50
                                seconds2 = 50
                                seconds3 = 50
                                seconds4 = 50
                                seconds5 = 50
                                seconds6 = 35
                                seconds7 = 50
                                seconds9 = 50
                                seconds10 = 50
                                seconds11 = 50
                                seconds12 = 50
                                seconds13 = 50
                                seconds14 = 50
                                seconds15 = 50
                                seconds16 = 50
                                seconds17 = 50
                                seconds18 = 50
                                seconds19 = 50
                                seconds20 = 50
                                seconds21 = 50
                                seconds22 = 50
                                seconds23 = 50
                                seconds24 = 35
                                seconds25 = 50
                                seconds26 = 50
                                valuess = "F"
                                
                                if valuess == "F":
                                    seconds8-=1
                                    cv2.putText(img, f'Timing: {int(seconds8)}', (0, 350), cv2.FONT_HERSHEY_COMPLEX, 1, (200, 200, 200), 2)
                                    
                                    if seconds8 == 1:
                                        txt2.insert(END, "F")
                                        seconds8 = 50
                                txt2.configure(state=tk.DISABLED)
                            if lmList[8][2]<lmList[6][2] and volPec4>20 and (lmList[tipIds[0]][1] > lmList[tipIds[0]-1][1]) and not(lmList[12][2]<lmList[10][2]) and not(lmList[16][2]<lmList[14][2]) and not(lmList[20][2]<lmList[18][2]):
                                cv2.rectangle(img, (20, 190), (140, 300), (0, 255, 0), cv2.FILLED)
                                cv2.putText(img, "L", (45, 280), cv2.FONT_HERSHEY_PLAIN, 5, (255, 0, 0), 5)
                                txt2.configure(state=tk.NORMAL)
                                seconds = 50
                                seconds1 = 50
                                seconds2 = 50
                                seconds3 = 50
                                seconds4 = 50
                                seconds5 = 50
                                seconds6 = 35
                                seconds7 = 50
                                seconds8 = 50
                                seconds10 = 50
                                seconds11 = 50
                                seconds12 = 50
                                seconds13 = 50
                                seconds14 = 50
                                seconds15 = 50
                                seconds16 = 50
                                seconds17 = 50
                                seconds18 = 50
                                seconds19 = 50
                                seconds20 = 50
                                seconds21 = 50
                                seconds22 = 50
                                seconds23 = 50
                                seconds24 = 35
                                seconds25 = 50
                                seconds26 = 50
                                valuess = "L"
                                
                                if valuess == "L":
                                    seconds9-=1
                                    cv2.putText(img, f'Timing: {int(seconds9)}', (0, 350), cv2.FONT_HERSHEY_COMPLEX, 1, (200, 200, 200), 2)
                                    
                                    if seconds9 == 1:
                                        txt2.insert(END, "L")
                                        seconds9 = 50
                                txt2.configure(state=tk.DISABLED)
                            if (volPec16<18) and (volPec17<18) and (volPec18<18) and lmList[8][2]<lmList[6][2] and not(lmList[tipIds[0]][1] > lmList[tipIds[0]-1][1]) and not(lmList[12][2]<lmList[10][2]) and not(lmList[16][2]<lmList[14][2]) and not(lmList[20][2]<lmList[18][2]):
                                cv2.rectangle(img, (20, 190), (140, 300), (0, 255, 0), cv2.FILLED)
                                cv2.putText(img, "X", (45, 280), cv2.FONT_HERSHEY_PLAIN, 5, (255, 0, 0), 5)
                                txt2.configure(state=tk.NORMAL)
                                seconds = 50
                                seconds1 = 50
                                seconds2 = 50
                                seconds3 = 50
                                seconds4 = 50
                                seconds5 = 50
                                seconds6 = 35
                                seconds7 = 50
                                seconds8 = 50
                                seconds9 = 50
                                seconds11 = 50
                                seconds12 = 50
                                seconds13 = 50
                                seconds14 = 50
                                seconds15 = 50
                                seconds16 = 50
                                seconds17 = 50
                                seconds18 = 50
                                seconds19 = 50
                                seconds20 = 50
                                seconds21 = 50
                                seconds22 = 50
                                seconds23 = 50
                                seconds24 = 35
                                seconds25 = 50
                                seconds26 = 50
                                valuess = "X"
                                
                                if valuess == "X":
                                    seconds10-=1
                                    cv2.putText(img, f'Timing: {int(seconds10)}', (0, 350), cv2.FONT_HERSHEY_COMPLEX, 1, (200, 200, 200), 2)
                                    
                                    if seconds10 == 1:
                                        txt2.insert(END, "X")
                                        seconds10 = 50
                                txt2.configure(state=tk.DISABLED)
                            if volPec>25 and volPec12<20 and not(lmList[8][2]<lmList[6][2]) and not(lmList[tipIds[0]][1] > lmList[tipIds[0]-1][1]) and not(lmList[12][2]<lmList[10][2]) and not(lmList[16][2]<lmList[14][2]) and not(lmList[20][2]<lmList[18][2]):
                                cv2.rectangle(img, (20, 190), (140, 300), (0, 255, 0), cv2.FILLED)
                                cv2.putText(img, "M", (45, 280), cv2.FONT_HERSHEY_PLAIN, 5, (255, 0, 0), 5)
                                txt2.configure(state=tk.NORMAL)
                                seconds = 50
                                seconds1 = 50
                                seconds2 = 50
                                seconds3 = 50
                                seconds4 = 50
                                seconds5 = 50
                                seconds6 = 35
                                seconds7 = 50
                                seconds8 = 50
                                seconds9 = 50
                                seconds10 = 50
                                seconds12 = 50
                                seconds13 = 50
                                seconds14 = 50
                                seconds15 = 50
                                seconds16 = 50
                                seconds17 = 50
                                seconds18 = 50
                                seconds19 = 50
                                seconds20 = 50
                                seconds21 = 50
                                seconds22 = 50
                                seconds23 = 50
                                seconds24 = 35
                                seconds25 = 50
                                seconds26 = 50
                                valuess = "M"
                                
                                if valuess == "M":
                                    seconds11-=1
                                    cv2.putText(img, f'Timing: {int(seconds11)}', (0, 350), cv2.FONT_HERSHEY_COMPLEX, 1, (200, 200, 200), 2)
                                
                                    if seconds11 == 1:
                                        txt2.insert(END, "M")
                                        seconds11 = 50
                                txt2.configure(state=tk.DISABLED)
                            if not(lmList[20][2]<lmList[18][2]) and volPec>20 and volPec12>20 and not(lmList[8][2]<lmList[6][2]) and not(lmList[tipIds[0]][1] > lmList[tipIds[0]-1][1]) and not(lmList[12][2]<lmList[10][2]) and not(lmList[16][2]<lmList[14][2]) and not(lmList[20][2]<lmList[18][2]):
                                cv2.rectangle(img, (20, 190), (140, 300), (0, 255, 0), cv2.FILLED)
                                cv2.putText(img, "N", (45, 280), cv2.FONT_HERSHEY_PLAIN, 5, (255, 0, 0), 5)
                                txt2.configure(state=tk.NORMAL)
                                seconds = 50
                                seconds1 = 50
                                seconds2 = 50
                                seconds3 = 50
                                seconds4 = 50
                                seconds5 = 50
                                seconds6 = 35
                                seconds7 = 50
                                seconds8 = 50
                                seconds9 = 50
                                seconds10 = 50
                                seconds11 = 50
                                seconds13 = 50
                                seconds14 = 50
                                seconds15 = 50
                                seconds16 = 50
                                seconds17 = 50
                                seconds18 = 50
                                seconds19 = 50
                                seconds20 = 50
                                seconds21 = 50
                                seconds22 = 50
                                seconds23 = 50
                                seconds24 = 35
                                seconds25 = 50
                                seconds26 = 50
                                valuess = "N"
                                
                                if valuess == "N":
                                    seconds12-=1
                                    cv2.putText(img, f'Timing: {int(seconds12)}', (0, 350), cv2.FONT_HERSHEY_COMPLEX, 1, (200, 200, 200), 2)
                                    
                                    if seconds12 == 1:
                                        txt2.insert(END, "N")
                                        seconds12 = 50
                                txt2.configure(state=tk.DISABLED)
                            if volPec<10 and volPec12>20 and (volPec4<5) and volPec13>20 and volPec14>20 and not(lmList[8][2]<lmList[6][2]) and not(lmList[tipIds[0]][1] > lmList[tipIds[0]-1][1]) and not(lmList[12][2]<lmList[10][2]) and not(lmList[16][2]<lmList[14][2]) and not(lmList[20][2]<lmList[18][2]):
                                cv2.rectangle(img, (20, 190), (140, 300), (0, 255, 0), cv2.FILLED)
                                cv2.putText(img, "S", (45, 280), cv2.FONT_HERSHEY_PLAIN, 5, (255, 0, 0), 5)
                                txt2.configure(state=tk.NORMAL)
                                seconds = 50
                                seconds1 = 50
                                seconds2 = 50
                                seconds3 = 50
                                seconds4 = 50
                                seconds5 = 50
                                seconds6 = 35
                                seconds7 = 50
                                seconds8 = 50
                                seconds9 = 50
                                seconds10 = 50
                                seconds11 = 50
                                seconds12 = 50
                                seconds14 = 50
                                seconds15 = 50
                                seconds16 = 50
                                seconds17 = 50
                                seconds18 = 50
                                seconds19 = 50
                                seconds20 = 50
                                seconds21 = 50
                                seconds22 = 50
                                seconds23 = 50
                                seconds24 = 35
                                seconds25 = 50
                                seconds26 = 50
                                valuess = "S"
                                
                                if valuess == "S":
                                    seconds13-=1
                                    cv2.putText(img, f'Timing: {int(seconds13)}', (0, 350), cv2.FONT_HERSHEY_COMPLEX, 1, (200, 200, 200), 2)
                                    print("s")
                                    if seconds13 == 1:
                                        txt2.insert(END, "S")
                                        seconds13 = 50
                                txt2.configure(state=tk.DISABLED)
                            if lmList[8][2]<lmList[6][2] and volPec<25 and not(lmList[tipIds[1]][1] > lmList[tipIds[1]-1][1]) and not(lmList[tipIds[0]][1] > lmList[tipIds[0]-1][1]) and not(lmList[12][2]<lmList[10][2]) and not(lmList[16][2]<lmList[14][2]) and not(lmList[20][2]<lmList[18][2]):
                                cv2.rectangle(img, (20, 190), (140, 300), (0, 255, 0), cv2.FILLED)
                                cv2.putText(img, "G", (45, 280), cv2.FONT_HERSHEY_PLAIN, 5, (255, 0, 0), 5)
                                txt2.configure(state=tk.NORMAL)
                                seconds = 50
                                seconds1 = 50
                                seconds2 = 50
                                seconds3 = 50
                                seconds4 = 50
                                seconds5 = 50
                                seconds6 = 35
                                seconds7 = 50
                                seconds8 = 50
                                seconds9 = 50
                                seconds10 = 50
                                seconds11 = 50
                                seconds12 = 50
                                seconds13 = 50
                                seconds15 = 50
                                seconds16 = 50
                                seconds17 = 50
                                seconds18 = 50
                                seconds19 = 50
                                seconds20 = 50
                                seconds21 = 50
                                seconds22 = 50
                                seconds23 = 50
                                seconds24 = 35
                                seconds25 = 50
                                seconds26 = 50
                                valuess = "G"
                                
                                if valuess == "G":
                                    seconds14-=1
                                    cv2.putText(img, f'Timing: {int(seconds14)}', (0, 350), cv2.FONT_HERSHEY_COMPLEX, 1, (200, 200, 200), 2)
                                    
                                    if seconds14 == 1:
                                        txt2.insert(END, "G")
                                        seconds14 = 50
                                txt2.configure(state=tk.DISABLED)
                            if (lmList[8][2]<lmList[6][2]) and volPec4<9 and volPec>25 and volPec12>15 and not(lmList[tipIds[1]][1] > lmList[tipIds[1]-1][1]) and not(lmList[tipIds[0]][1] > lmList[tipIds[0]-1][1]) and not(lmList[12][2]<lmList[10][2]) and not(lmList[16][2]<lmList[14][2]) and not(lmList[20][2]<lmList[18][2]):
                                cv2.rectangle(img, (20, 190), (140, 300), (0, 255, 0), cv2.FILLED)
                                cv2.putText(img, "P", (45, 280), cv2.FONT_HERSHEY_PLAIN, 5, (255, 0, 0), 5)
                                txt2.configure(state=tk.NORMAL)
                                seconds = 50
                                seconds1 = 50
                                seconds2 = 50
                                seconds3 = 50
                                seconds4 = 50
                                seconds5 = 50
                                seconds6 = 35
                                seconds7 = 50
                                seconds8 = 50
                                seconds9 = 50
                                seconds10 = 50
                                seconds11 = 50
                                seconds12 = 50
                                seconds13 = 50
                                seconds14 = 50
                                seconds16 = 50
                                seconds17 = 50
                                seconds18 = 50
                                seconds19 = 50
                                seconds20 = 50
                                seconds21 = 50
                                seconds22 = 50
                                seconds23 = 50
                                seconds24 = 35
                                seconds25 = 50
                                seconds26 = 50
                                valuess = "P"
                                
                                if valuess == "P":
                                    seconds15-=1
                                    cv2.putText(img, f'Timing: {int(seconds15)}', (0, 350), cv2.FONT_HERSHEY_COMPLEX, 1, (200, 200, 200), 2)
                                    if seconds15 == 1:
                                        print("values")
                                        txt2.insert(END, "P")
                                        seconds15 = 50
                                txt2.configure(state=tk.DISABLED)
                            if lmList[20][2]<lmList[18][2] and volPec12>35 and not(lmList[tipIds[0]][1] > lmList[tipIds[0]-1][1]) and not(lmList[12][2]<lmList[10][2]) and not(lmList[16][2]<lmList[14][2]) and not(lmList[8][2]<lmList[6][2]):
                                cv2.rectangle(img, (20, 190), (140, 300), (0, 255, 0), cv2.FILLED)
                                cv2.putText(img, "I", (45, 280), cv2.FONT_HERSHEY_PLAIN, 5, (255, 0, 0), 5)
                                txt2.configure(state=tk.NORMAL)
                                seconds = 50
                                seconds1 = 50
                                seconds2 = 50
                                seconds3 = 50
                                seconds4 = 50
                                seconds5 = 50
                                seconds6 = 35
                                seconds7 = 50
                                seconds8 = 50
                                seconds9 = 50
                                seconds10 = 50
                                seconds11 = 50
                                seconds12 = 50
                                seconds13 = 50
                                seconds14 = 50
                                seconds15 = 50
                                seconds17 = 50
                                seconds18 = 50
                                seconds19 = 50
                                seconds20 = 50
                                seconds21 = 50
                                seconds22 = 50
                                seconds23 = 50
                                seconds24 = 35
                                seconds25 = 50
                                seconds26 = 50
                                valuess = "I"
                                
                                if valuess == "I":
                                    seconds16-=1
                                    cv2.putText(img, f'Timing: {int(seconds16)}', (0, 350), cv2.FONT_HERSHEY_COMPLEX, 1, (200, 200, 200), 2)
                                    
                                    if seconds16 == 1:
                                        txt2.insert(END, "I")
                                        seconds16 = 50
                                txt2.configure(state=tk.DISABLED)
                            if (lmList[20][2]<lmList[18][2]) and volPec<5 and volPec12>15 and not(lmList[tipIds[4]][1] > lmList[tipIds[4]-1][1]) and not(lmList[tipIds[0]][1] > lmList[tipIds[0]-1][1]) and not(lmList[12][2]<lmList[10][2]) and not(lmList[16][2]<lmList[14][2]) and not(lmList[8][2]<lmList[6][2]):
                                cv2.rectangle(img, (20, 190), (140, 300), (0, 255, 0), cv2.FILLED)
                                cv2.putText(img, "J", (45, 280), cv2.FONT_HERSHEY_PLAIN, 5, (255, 0, 0), 5)
                                txt2.configure(state=tk.NORMAL)
                                seconds = 50
                                seconds1 = 50
                                seconds2 = 50
                                seconds3 = 50
                                seconds4 = 50
                                seconds5 = 50
                                seconds6 = 35
                                seconds7 = 50
                                seconds8 = 50
                                seconds9 = 50
                                seconds10 = 50
                                seconds11 = 50
                                seconds12 = 50
                                seconds13 = 50
                                seconds14 = 50
                                seconds15 = 50
                                seconds16 = 50
                                seconds18 = 50
                                seconds19 = 50
                                seconds20 = 50
                                seconds21 = 50
                                seconds22 = 50
                                seconds23 = 50
                                seconds24 = 35
                                seconds25 = 50
                                seconds26 = 50
                                valuess = "J"
                                
                                if valuess == "J":
                                    seconds17-=1
                                    cv2.putText(img, f'Timing: {int(seconds17)}', (0, 350), cv2.FONT_HERSHEY_COMPLEX, 1, (200, 200, 200), 2)
                                    
                                    if seconds17 == 1:
                                        txt2.insert(END, "J")
                                        seconds17 = 50
                                txt2.configure(state=tk.DISABLED)
                            if lmList[8][2]<lmList[6][2] and (volPec12<20) and volPec>20 and (lmList[tipIds[1]][1] > lmList[tipIds[1]-1][1]) and not(lmList[tipIds[0]][1] > lmList[tipIds[0]-1][1]) and (lmList[12][2]<lmList[10][2]) and not(lmList[16][2]<lmList[14][2]) and not(lmList[20][2]<lmList[18][2]):
                                cv2.rectangle(img, (20, 190), (140, 300), (0, 255, 0), cv2.FILLED)
                                cv2.putText(img, "V", (45, 280), cv2.FONT_HERSHEY_PLAIN, 5, (255, 0, 0), 5)
                                txt2.configure(state=tk.NORMAL)
                                seconds = 50
                                seconds1 = 50
                                seconds2 = 50
                                seconds3 = 50
                                seconds4 = 50
                                seconds5 = 50
                                seconds6 = 35
                                seconds7 = 50
                                seconds8 = 50
                                seconds9 = 50
                                seconds10 = 50
                                seconds11 = 50
                                seconds12 = 50
                                seconds13 = 50
                                seconds14 = 50
                                seconds15 = 50
                                seconds16 = 50
                                seconds17 = 50
                                seconds19 = 50
                                seconds20 = 50
                                seconds21 = 50
                                seconds22 = 50
                                seconds23 = 50
                                seconds24 = 35
                                seconds25 = 50
                                seconds26 = 50
                                valuess = "V"
                                
                                if valuess == "V":
                                    seconds18-=1
                                    cv2.putText(img, f'Timing: {int(seconds18)}', (0, 350), cv2.FONT_HERSHEY_COMPLEX, 1, (200, 200, 200), 2)
                                    
                                    if seconds18 == 1:
                                        txt2.insert(END, "V")
                                        seconds18 = 50
                                txt2.configure(state=tk.DISABLED)
                            if (lmList[8][2]<lmList[6][2]) and (volPec12>15) and (volPec13>15) and volPec<20 and  (lmList[tipIds[1]][1] > lmList[tipIds[1]-1][1]) and not(lmList[tipIds[0]][1] > lmList[tipIds[0]-1][1]) and (lmList[12][2]<lmList[10][2]) and not(lmList[16][2]<lmList[14][2]) and not(lmList[20][2]<lmList[18][2]):
                                cv2.rectangle(img, (20, 190), (140, 300), (0, 255, 0), cv2.FILLED)
                                cv2.putText(img, "K", (45, 280), cv2.FONT_HERSHEY_PLAIN, 5, (255, 0, 0), 5)
                                txt2.configure(state=tk.NORMAL)
                                seconds = 50
                                seconds1 = 50
                                seconds2 = 50
                                seconds3 = 50
                                seconds4 = 50
                                seconds5 = 50
                                seconds6 = 35
                                seconds7 = 50
                                seconds8 = 50
                                seconds9 = 50
                                seconds10 = 50
                                seconds11 = 50
                                seconds12 = 50
                                seconds13 = 50
                                seconds14 = 50
                                seconds15 = 50
                                seconds16 = 50
                                seconds17 = 50
                                seconds18 = 50
                                seconds20 = 50
                                seconds21 = 50
                                seconds22 = 50
                                seconds23 = 50
                                seconds24 = 35
                                seconds25 = 50
                                seconds26 = 50
                                valuess = "K"
                                
                                if valuess == "K":
                                    seconds19-=1
                                    cv2.putText(img, f'Timing: {int(seconds19)}', (0, 350), cv2.FONT_HERSHEY_COMPLEX, 1, (200, 200, 200), 2)
                                    
                                    if seconds19 == 1:
                                        txt2.insert(END, "K")
                                        seconds19 = 50
                                txt2.configure(state=tk.DISABLED)
                            if lmList[8][2]<lmList[6][2] and not(lmList[tipIds[0]][1] > lmList[tipIds[0]-1][1]) and (lmList[12][2]<lmList[10][2]) and (lmList[16][2]<lmList[14][2]) and not(lmList[20][2]<lmList[18][2]):
                                cv2.rectangle(img, (20, 190), (140, 300), (0, 255, 0), cv2.FILLED)
                                cv2.putText(img, "W", (45, 280), cv2.FONT_HERSHEY_PLAIN, 5, (255, 0, 0), 5)
                                txt2.configure(state=tk.NORMAL)
                                seconds = 50
                                seconds1 = 50
                                seconds2 = 50
                                seconds3 = 50
                                seconds4 = 50
                                seconds5 = 50
                                seconds6 = 35
                                seconds7 = 50
                                seconds8 = 50
                                seconds9 = 50
                                seconds10 = 50
                                seconds11 = 50
                                seconds12 = 50
                                seconds13 = 50
                                seconds14 = 50
                                seconds15 = 50
                                seconds16 = 50
                                seconds17 = 50
                                seconds18 = 50
                                seconds19 = 50
                                seconds21 = 50
                                seconds22 = 50
                                seconds23 = 50
                                seconds24 = 35
                                seconds25 = 50
                                seconds26 = 50
                                valuess = "W"
                                
                                if valuess == "W":
                                    seconds20-=1
                                    cv2.putText(img, f'Timing: {int(seconds20)}', (0, 350), cv2.FONT_HERSHEY_COMPLEX, 1, (200, 200, 200), 2)
                                    
                                    if seconds20 == 1:
                                        txt2.insert(END, "W")
                                        seconds20 = 50
                                txt2.configure(state=tk.DISABLED)
                            if lmList[8][2]<lmList[6][2] and (lmList[tipIds[2]][1] > lmList[tipIds[2]-1][1]) and (volPec>30) and (volPec4>30) and not(lmList[tipIds[1]][1] > lmList[tipIds[1]-1][1]) and not(lmList[tipIds[0]][1] > lmList[tipIds[0]-1][1]) and (lmList[12][2]<lmList[10][2]) and not(lmList[16][2]<lmList[14][2]) and not(lmList[20][2]<lmList[18][2]):
                                cv2.rectangle(img, (20, 190), (140, 300), (0, 255, 0), cv2.FILLED)
                                cv2.putText(img, "R", (45, 280), cv2.FONT_HERSHEY_PLAIN, 5, (255, 0, 0), 5)
                                txt2.configure(state=tk.NORMAL)
                                seconds = 50
                                seconds1 = 50
                                seconds2 = 50
                                seconds3 = 50
                                seconds4 = 50
                                seconds5 = 50
                                seconds6 = 35
                                seconds7 = 50
                                seconds8 = 50
                                seconds9 = 50
                                seconds10 = 50
                                seconds11 = 50
                                seconds12 = 50
                                seconds13 = 50
                                seconds14 = 50
                                seconds15 = 50
                                seconds16 = 50
                                seconds17 = 50
                                seconds18 = 50
                                seconds19 = 50
                                seconds20 = 50
                                seconds22 = 50
                                seconds23 = 50
                                seconds24 = 35
                                seconds25 = 50
                                seconds26 = 50
                                valuess = "R"
                                
                                if valuess == "R": 
                                    seconds21-=1
                                    cv2.putText(img, f'Timing: {int(seconds21)}', (0, 350), cv2.FONT_HERSHEY_COMPLEX, 1, (200, 200, 200), 2)
                                    
                                    if seconds21 == 1:
                                        txt2.insert(END, "R")
                                        seconds21 = 50
                                txt2.configure(state=tk.DISABLED)
                            if  not(lmList[tipIds[2]][1] > lmList[tipIds[2]-1][1]) and (volPec>30) and (volPec4>30) and not(lmList[tipIds[1]][1] > lmList[tipIds[1]-1][1]) and not(lmList[tipIds[0]][1] > lmList[tipIds[0]-1][1]) and (lmList[12][2]<lmList[10][2]) and not(lmList[16][2]<lmList[14][2]) and not(lmList[20][2]<lmList[18][2]):
                                cv2.rectangle(img, (20, 190), (140, 300), (0, 255, 0), cv2.FILLED)
                                cv2.putText(img, "U", (45, 280), cv2.FONT_HERSHEY_PLAIN, 5, (255, 0, 0), 5)
                                txt2.configure(state=tk.NORMAL)
                                seconds = 50
                                seconds1 = 50
                                seconds2 = 50
                                seconds3 = 50
                                seconds4 = 50
                                seconds5 = 50
                                seconds6 = 35
                                seconds7 = 50
                                seconds8 = 50
                                seconds9 = 50
                                seconds10 = 50
                                seconds11 = 50
                                seconds12 = 50
                                seconds13 = 50
                                seconds14 = 50
                                seconds15 = 50
                                seconds16 = 50
                                seconds17 = 50
                                seconds18 = 50
                                seconds19 = 50
                                seconds20 = 50
                                seconds21 = 50
                                seconds22 = 50
                                seconds23 = 50
                                seconds24 = 35
                                seconds25 = 50
                                valuess = "U"
                                
                                if valuess == "U":
                                    seconds26-=1
                                    cv2.putText(img, f'Timing: {int(seconds26)}', (0, 350), cv2.FONT_HERSHEY_COMPLEX, 1, (200, 200, 200), 2)
                                    
                                    if seconds26 == 1:
                                        txt2.insert(END, "U")
                                        seconds26 = 50
                                txt2.configure(state=tk.DISABLED)    
                            if lmList[8][2]<lmList[6][2] and (volPec<30) and (volPec4<30) and not(lmList[tipIds[2]][1] > lmList[tipIds[2]-1][1]) and not(lmList[tipIds[1]][1] > lmList[tipIds[1]-1][1]) and not(lmList[tipIds[0]][1] > lmList[tipIds[0]-1][1]) and (lmList[12][2]<lmList[10][2]) and not(lmList[16][2]<lmList[14][2]) and not(lmList[20][2]<lmList[18][2]):
                                cv2.rectangle(img, (20, 190), (140, 300), (0, 255, 0), cv2.FILLED)
                                cv2.putText(img, "H", (45, 280), cv2.FONT_HERSHEY_PLAIN, 5, (255, 0, 0), 5)
                                txt2.configure(state=tk.NORMAL)
                                seconds = 50
                                seconds1 = 50
                                seconds2 = 50
                                seconds3 = 50
                                seconds4 = 50
                                seconds5 = 50
                                seconds6 = 35
                                seconds7 = 50
                                seconds8 = 50
                                seconds9 = 50
                                seconds10 = 50
                                seconds11 = 50
                                seconds12 = 50
                                seconds13 = 50
                                seconds14 = 50
                                seconds15 = 50
                                seconds16 = 50
                                seconds17 = 50
                                seconds18 = 50
                                seconds19 = 50
                                seconds20 = 50
                                seconds21 = 50
                                seconds23 = 50
                                seconds24 = 35
                                seconds25 = 50
                                seconds26 = 50
                                valuess = "H"
                                
                                if valuess == "H":
                                    seconds22-=1
                                    cv2.putText(img, f'Timing: {int(seconds22)}', (0, 350), cv2.FONT_HERSHEY_COMPLEX, 1, (200, 200, 200), 2)
                                    
                                    if seconds22 == 1:
                                        txt2.insert(END, "H")
                                        seconds22 = 50
                                txt2.configure(state=tk.DISABLED)
                            if lmList[20][2]<lmList[18][2] and volPec12>35 and (lmList[tipIds[0]][1] > lmList[tipIds[0]-1][1]) and not(lmList[12][2]<lmList[10][2]) and not(lmList[16][2]<lmList[14][2]) and not(lmList[8][2]<lmList[6][2]):
                                cv2.rectangle(img, (20, 190), (140, 300), (0, 255, 0), cv2.FILLED)
                                cv2.putText(img, "Y", (45, 280), cv2.FONT_HERSHEY_PLAIN, 5, (255, 0, 0), 5)
                                txt2.configure(state=tk.NORMAL)
                                seconds = 50
                                seconds1 = 50
                                seconds2 = 50
                                seconds3 = 50
                                seconds4 = 50
                                seconds5 = 50
                                seconds6 = 35
                                seconds7 = 50
                                seconds8 = 50
                                seconds9 = 50
                                seconds10 = 50
                                seconds11 = 50
                                seconds12 = 50
                                seconds13 = 50
                                seconds14 = 50
                                seconds15 = 50
                                seconds16 = 50
                                seconds17 = 50
                                seconds18 = 50
                                seconds19 = 50
                                seconds20 = 50
                                seconds21 = 50
                                seconds22 = 50
                                seconds24 = 35
                                seconds25 = 50
                                seconds26 = 50
                                valuess = "Y"
                                
                                if valuess == "Y":
                                    seconds23-=1
                                    cv2.putText(img, f'Timing: {int(seconds23)}', (0, 350), cv2.FONT_HERSHEY_COMPLEX, 1, (200, 200, 200), 2)
                                    
                                    if seconds23 == 1:
                                        txt2.insert(END, "Y")
                                        seconds23 = 50
                                txt2.configure(state=tk.DISABLED)
                        except:
                            pass
                    #defination of cancels fuction to cancel hand gestures 
                    def cancels():
                        txt2.configure(state=tk.NORMAL)
                        input_string3 = (txt2.get('1.0', END))
                        txt2.delete("1.0",END)
                        input_string3 = input_string3[:-2]
                        print(input_string3)
                        txt2.insert(END, input_string3)
                        txt2.configure(state=tk.DISABLED)
                        
                    #intialization of input_string1 with tx2 extry content
                    input_string1 = (txt2.get('1.0', END))
                    

                    #writing on webcam frame
                    cv2.putText(img, "Sentence formation bellow ", (0, 420), cv2.FONT_HERSHEY_COMPLEX, 1, (200, 200, 200), 1)
                    cv2.putText(img, input_string1, (0, 450), cv2.FONT_HERSHEY_COMPLEX, 1, (200, 200, 200), 2)

                    #creation of opencv imshow function to show detections and everything to be desplayed on webcam
                    cv2.imshow("Image", img)
                    #terminate or destroy webcam
                    if cv2.waitKey(10) & 0xFF == ord('q'):
                        break
                #release webcam
                cap.release()
                #destroy webcam
                cv2.destroyAllWindows()
                #creation of move fuction to remove duplicates
                move()
                #creation of talks function to output speech 
                talks()
            #defining client_sends function to sent message to another client
            def client_sends():
                txt.configure(state=tk.NORMAL)
                words4.set(str(txt2.get('1.0', END)))

                if len(txt2.get("1.0", END)) == 1 & len(txt2.get("1.0", END)) == len(words4.get()):
                    print("fffffffffff")
                    client_sends = tkinter.messagebox.showwarning("SIGNING SCREEN", "Sentence formation screen is empty")
                    return

                #creation of client_send function
                def client_send():
                    message = f'{alias}: {words4.get()}'
                    client.send(message.encode('utf-8'))
                    txt2.configure(state=tk.NORMAL)
                    words5.set(str(txt2.get('1.0', END)))

                    txt2.configure(state=tk.NORMAL)
                    txt2.delete("1.0",END)
                    txt2.configure(state=tk.DISABLED)

                #creation of client_send function
                send_thread = threading.Thread(target=client_send)
                send_thread.start()
                txt.configure(state=tk.DISABLED)

            def HHands():
                try:
                    # Initialize the mediapipe hands class.
                    mp_hands = mp.solutions.hands

                    # Set up the Hands function.
                    hands = mp_hands.Hands(static_image_mode=True, max_num_hands=2, min_detection_confidence=0.3)

                    # Initialize the mediapipe drawing class.
                    mp_drawing = mp.solutions.drawing_utils

                    mp_holistic = mp.solutions.holistic
                    face = mp_holistic.Holistic()

                    def detectHandsLandmarks(image, hands, display = True):
                        # Create a copy of the input image to draw landmarks on.
                        output_image = image.copy()

                        # Convert the image from BGR into RGB format.
                        imgRGB = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

                        # Perform the Hands Landmarks Detection.
                        results = hands.process(imgRGB)

                        # Check if landmarks are found.
                        if results.multi_hand_landmarks:

                            # Iterate over the found hands.
                            for hand_landmarks in results.multi_hand_landmarks:

                                # Draw the hand landmarks on the copy of the input image.
                                mp_drawing.draw_landmarks(image = output_image, landmark_list = hand_landmarks,
                                                      connections = mp_hands.HAND_CONNECTIONS) 

                        # Check if the original input image and the output image are specified to be displayed.
                        if display:

                            # Display the original input image and the output image.
                            plt.figure(figsize=[15,15])
                            plt.subplot(121);plt.imshow(image[:,:,::-1]);plt.title("Original Image");plt.axis('off');
                            plt.subplot(122);plt.imshow(output_image[:,:,::-1]);plt.title("Output");plt.axis('off');

                        # Otherwise
                        else:

                            # Return the output image and results of hands landmarks detection.
                            return output_image, results              
                    def getHandType(image, results, draw=True, display = True):
                        # Create a copy of the input image to write hand type label on.
                        output_image = image.copy()

                        # Initialize a dictionary to store the classification info of both hands.
                        hands_status = {'Right': False, 'Left': False, 'Right_index' : None, 'Left_index': None}

                        # Iterate over the found hands in the image.
                        for hand_index, hand_info in enumerate(results.multi_handedness):

                            # Retrieve the label of the found hand.
                            hand_type = hand_info.classification[0].label

                            # Update the status of the found hand.
                            hands_status[hand_type] = True

                            # Update the index of the found hand.
                            hands_status[hand_type + '_index'] = hand_index 

                            # Check if the hand type label is specified to be written.
                            if draw:

                                # Write the hand type on the output image. 
                                cv2.putText(output_image, hand_type + ' Hand Detected', (10, (hand_index+1) * 30),cv2.FONT_HERSHEY_PLAIN,
                                            3, (0,0,255), 3)

                        # Check if the output image is specified to be displayed.
                        if display:

                            # Display the output image.
                            plt.figure(figsize=[10,10])
                            plt.imshow(output_image[:,:,::-1]);plt.title("Output Image");plt.axis('off');

                        # Otherwise
                        else:

                            # Return the output image and the hands status dictionary that contains classification info.
                            return output_image, hands_status

                    def drawBoundingBoxes(image, results, hand_status, padd_amount = 10, draw=True, display=True):  
                        # Create a copy of the input image to draw bounding boxes on and write hands types labels.
                        output_image = image.copy()

                        # Initialize a dictionary to store both (left and right) hands landmarks as different elements.
                        output_landmarks = {}

                        # Get the height and width of the input image.
                        height, width, _ = image.shape

                        # Iterate over the found hands.
                        for hand_index, hand_landmarks in enumerate(results.multi_hand_landmarks):

                            # Initialize a list to store the detected landmarks of the hand.
                            landmarks = []

                            # Iterate over the detected landmarks of the hand.
                            for landmark in hand_landmarks.landmark:

                                # Append the landmark into the list.
                                landmarks.append((int(landmark.x * width), int(landmark.y * height),
                                                      (landmark.z * width)))

                            # Get all the x-coordinate values from the found landmarks of the hand.
                            x_coordinates = np.array(landmarks)[:,0]

                            # Get all the y-coordinate values from the found landmarks of the hand.
                            y_coordinates = np.array(landmarks)[:,1]

                            # Get the bounding box coordinates for the hand with the specified padding.
                            x1  = int(np.min(x_coordinates) - padd_amount)
                            y1  = int(np.min(y_coordinates) - padd_amount)
                            x2  = int(np.max(x_coordinates) + padd_amount)
                            y2  = int(np.max(y_coordinates) + padd_amount)

                            # Initialize a variable to store the label of the hand.
                            label = "Unknown"

                            # Check if the hand we are iterating upon is the right one.
                            if hand_status['Right_index'] == hand_index:

                                # Update the label and store the landmarks of the hand in the dictionary. 
                                label = 'Right Hand'
                                output_landmarks['Right'] = landmarks

                            # Check if the hand we are iterating upon is the left one.
                            elif hand_status['Left_index'] == hand_index:

                                # Update the label and store the landmarks of the hand in the dictionary. 
                                label = 'Left Hand'
                                output_landmarks['Left'] = landmarks

                            # Check if the bounding box and the classified label is specified to be written.
                            if draw:

                                # Draw the bounding box around the hand on the output image.
                                cv2.rectangle(output_image, (x1, y1), (x2, y2), (155, 255, 255), 3, cv2.LINE_8)

                                # Write the classified label of the hand below the bounding box drawn. 
                                cv2.putText(output_image, label, (x1, y2+25), cv2.FONT_HERSHEY_COMPLEX, 0.7, (255,255,155), 1, cv2.LINE_AA)

                        # Check if the output image is specified to be displayed.
                        if display:

                            # Display the output image.
                            plt.figure(figsize=[10,10])
                            plt.imshow(output_image[:,:,::-1]);plt.title("Output Image");plt.axis('off');

                        # Otherwise
                        else:

                            # Return the output image and the landmarks dictionary.
                            return output_image, output_landmarks

                    hands_video = mp_hands.Hands(static_image_mode=False, max_num_hands=2,
                                                 min_detection_confidence=0.7, min_tracking_confidence=0.4)

                    # Initialize the VideoCapture object to read from the webcam.
                    camera_video = cv2.VideoCapture(0)
                    camera_video.set(3,1280)
                    camera_video.set(4,960)

                    # Initialize a resizable window.
                    cv2.namedWindow('Hands Landmarks Detection')

                    # Iterate until the webcam is accessed successfully.
                    while camera_video.isOpened():

                        # Read a frame.
                        ok, frame = camera_video.read()

                        # Check if frame is not read properly then continue to the next iteration to read the next frame.
                        if not ok:
                            continue

                        # Flip the frame horizontally for natural (selfie-view) visualization.
                        frame = cv2.flip(frame, 1)

                        # Perform Hands landmarks detection.
                        frame, results = detectHandsLandmarks(frame, hands_video, display=False)

                        # Check if landmarks are found in the frame.
                        if results.multi_hand_landmarks:

                            # Perform hand(s) type (left or right) classification.
                            _, hands_status = getHandType(frame.copy(), results, draw=False, display=False)

                            # Draw bounding boxes around the detected hands and write their classified types near them.
                            frame, _ = drawBoundingBoxes(frame, results, hands_status, display=False)

                        # Display the frame.
                        cv2.imshow('Hands Landmarks Detection', frame)

                        # Wait for 1ms. If a a key is pressed, retreive the ASCII code of the key.
                        if cv2.waitKey(10) & 0xFF == ord('q'):
                            break

                    # Release the VideoCapture Object and close the windows.                  
                    camera_video.release()
                    cv2.destroyAllWindows()
                except:
                    pass
            def VCHands():
                try:
                    ################################
                    wCam, hCam = 640, 480
                    ################################

                    cap = cv2.VideoCapture(0)
                    cap.set(3, wCam)
                    cap.set(4, hCam)
                    pTime = 0

                    detector = htm1.handDetector(detectionCon=0.7, maxHands=1)

                    devices = AudioUtilities.GetSpeakers()
                    interface = devices.Activate(
                        IAudioEndpointVolume._iid_, CLSCTX_ALL, None)
                    volume = cast(interface, POINTER(IAudioEndpointVolume))
                    # volume.GetMute()
                    # volume.GetMasterVolumeLevel()
                    volRange = volume.GetVolumeRange()
                    minVol = volRange[0]
                    maxVol = volRange[1]
                    vol = 0
                    volBar = 400
                    volPer = 0
                    area = 0
                    colorVol = (255, 0, 0)
                    lmList=""
                    #bbox
                    while True:
                        success, imgs = cap.read()

                        # Find Hand
                        imgs = detector.findHands(imgs)
                        try:
                            lmList, bbox = detector.findPosition(imgs, draw=True)
                        except:
                            pass
                        if len(lmList) != 0:
                            # Filter based on size
                            area = (bbox[2] - bbox[0]) * (bbox[3] - bbox[1]) // 100
                            # print(area)
                            if 250 < area < 1000:

                                try:
                                    # Find Distance between index and Thumb
                                    length, imgs, lineInfo = detector.findDistance(4, 8, imgs)
                                    # print(length)

                                    # Convert Volume
                                    volBar = np.interp(length, [50, 200], [400, 150])
                                    volPer = np.interp(length, [50, 200], [0, 100])

                                    # Reduce Resolution to make it smoother
                                    smoothness = 10
                                    volPer = smoothness * round(volPer / smoothness)

                                    # Check fingers up
                                    fingers = detector.fingersUp()
                                    # print(fingers)

                                    # If pinky is down set volume
                                    if not fingers[3]:
                                        volume.SetMasterVolumeLevelScalar(volPer / 100, None)
                                        cv2.circle(imgs, (lineInfo[4], lineInfo[5]), 15, (0, 255, 0), cv2.FILLED)
                                        colorVol = (0, 255, 0)
                                    else:
                                        colorVol = (255, 0, 0)
                                except:
                                    pass

                        # Drawings
                        cv2.rectangle(imgs, (50, 150), (85, 400), (255, 0, 0), 3)
                        cv2.rectangle(imgs, (50, int(volBar)), (85, 400), (255, 0, 0), cv2.FILLED)
                        cv2.putText(imgs, f'{int(volPer)} %', (40, 450), cv2.FONT_HERSHEY_COMPLEX,
                                    1, (255, 0, 0), 3)
                        cVol = int(volume.GetMasterVolumeLevelScalar() * 100)
                        cv2.putText(imgs, f'Vol Set: {int(cVol)}', (400, 50), cv2.FONT_HERSHEY_COMPLEX,
                                    1, colorVol, 3)

                        # Frame rate
                        cTime = time.time()
                        fps = 1 / (cTime - pTime)
                        pTime = cTime
                        cv2.putText(imgs, f'FPS: {int(fps)}', (40, 50), cv2.FONT_HERSHEY_COMPLEX,
                                    1, (255, 0, 0), 3)

                        cv2.imshow("Img", imgs)
                        if cv2.waitKey(10) & 0xFF == ord('q'):
                            break
                    cap.release()
                    cv2.destroyAllWindows()
                except:
                    pass
            #defining Recognition function for facial expression detection
            def VHands(): 
                try:
                    cap = cv2.VideoCapture(0)
                    cap.set(3, 1280)
                    cap.set(4, 720)

                    detector = HandDetector(detectionCon=0.8)
                    keys = [["Q", "W", "E", "R", "T", "Y", "U", "I", "O", "P"],
                            ["A", "S", "D", "F", "G", "H", "J", "K", "L", ";"],
                            ["Z", "X", "C", "V", "B", "N", "M", ",", ".", "/"]]
                    
                    finalText = ""

                    keyboard = Controller()


                    def drawAll(img, buttonList):
                        for button in buttonList:
                            x, y = button.pos
                            w, h = button.size
                            cvzone.cornerRect(img, (button.pos[0], button.pos[1], button.size[0], button.size[1]),
                                              20, rt=0)
                            cv2.rectangle(img, button.pos, (x + w, y + h), (0, 0, 0), cv2.FILLED)
                            cv2.putText(img, button.text, (x + 20, y + 65),
                                        cv2.FONT_HERSHEY_PLAIN, 4, (255, 255, 255), 4)
                        return img
                    
                    class Button():
                        def __init__(self, pos, text, size=[85, 85]):
                            self.pos = pos
                            self.size = size
                            self.text = text


                    buttonList = []
                    for i in range(len(keys)):
                        for j, key in enumerate(keys[i]):
                            buttonList.append(Button([100 * j + 50, 100 * i + 50], key))

                    while True:
                        success, img = cap.read()
                        img = detector.findHands(img)
                        lmList, bboxInfo = detector.findPosition(img)
                        img = drawAll(img, buttonList)

                        if lmList:
                            for button in buttonList:
                                x, y = button.pos
                                w, h = button.size

                                if x < lmList[8][0] < x + w and y < lmList[8][1] < y + h:
                                    cv2.rectangle(img, (x - 5, y - 5), (x + w + 5, y + h + 5), (0, 255, 0), cv2.FILLED)
                                    cv2.putText(img, button.text, (x + 20, y + 65),
                                                cv2.FONT_HERSHEY_PLAIN, 4, (255, 255, 255), 4)
                                    l, _, _ = detector.findDistance(8, 12, img, draw=False)
                                    print(l)

                                    ## when clicked
                                    if l < 30:
                                        keyboard.press(button.text)
                                        cv2.rectangle(img, button.pos, (x + w, y + h), (255, 255, 255), cv2.FILLED)
                                        cv2.putText(img, button.text, (x + 20, y + 65),
                                                    cv2.FONT_HERSHEY_PLAIN, 4, (255, 255, 255), 4)
                                        finalText += button.text
                                        sleep(0.15)

                        cv2.rectangle(img, (50, 450), (1200, 600), (0, 0, 0), cv2.FILLED)
                        cv2.putText(img, finalText, (60, 530),
                                    cv2.FONT_HERSHEY_PLAIN, 5, (255, 255, 255), 5)

                        cv2.imshow("Image", img)
                        if cv2.waitKey(1) & 0xFF==ord("q"):
                            break
                    cap.release()
                    #destroy webcam
                    cv2.destroyAllWindows()
                except:
                    pass
            try:
                #defining move function to remove duplecates
                def move():
                    family_list = []
                    input_string = StringVar()

                    input_string.set(str(txt2.get('1.0', END)))


                    family_list = input_string.get().split(" ")
                    print(family_list)

                    txt2.configure(state=tk.NORMAL)
                    txt2.delete("1.0",END)
                    txt2.configure(state=tk.DISABLED)

                    def removeAllConsecutive(frfg):
                        result = []
                        for (key,group) in groupby(family_list):
                             result.append(key)
                        txt2.configure(state=tk.NORMAL)
                        txt2.insert(END, ' '.join(result))
                        txt2.configure(state=tk.DISABLED)
                    removeAllConsecutive(family_list)
                #defining talks function
                def talks():
                    txt2.configure(state=tk.NORMAL)
                    words5.set(str(txt2.get('1.0', END)))
                    engine=pyttsx3.init()
                    engine.say(words5.get())
                    engine.setProperty('rate', 150)
                    rate = engine.getProperty('rate')# getting details of current speaking rate


                    engine.runAndWait()
                    txt2.configure(state=tk.DISABLED)

                #defining homes function
                def homes():
                    self.root.destroy()
                    print("Helloqw")
                    Home(user_name)

                #defining exit function
                def Exit():
                    Exit = tkinter.messagebox.askyesno("SIGNING SCREEN", "confirm if you want to exit")
                    if Exit>0:
                        self.root.destroy()
                        return
                #defining Choose function to choose wheather you want to use hand gesture or facial expressions
                def Choose():
                    #creation of Hands function
                    Hands()
                def VChoose():
                    #creation of Hands function
                    VHands()
                def HChoose():
                    #creation of Hands function
                    HHands()
                def VCChoose():
                    #creation of Hands function
                    VCHands()
                #=======================================================================================================
                #creation of Activate button to call Choose function
                self.btnActivate = Button(topFrame, pady=1, bd=4, fg="black", font=('arial',16,'bold'), padx=24,
                                             width=10, command= VChoose, text="Virtual Keyboard").grid(row=0, column=1, padx=1)

                #creation of Home button to call homes function which will help to navigate back to Home screen
                self.btnHome = Button(topFrame, pady=1, bd=4, fg="black", font=('arial', 16, 'bold'), padx=24,
                                             width=10, command=homes, text="Home").grid(row=0, column=0, padx=1)

                #creation of Exit button to call exit function
                self.btnExit = Button(topFrame, pady=1, bd=4, fg="black", font=('arial', 16, 'bold'), padx=24,
                                       width=10, command = Choose, text="Sign language").grid(row=0, column=2, padx=1)
                self.btnExit = Button(topFrame, pady=1, bd=4, fg="black", font=('arial', 16, 'bold'), padx=24,
                                       width=10, command = HChoose, text="Hand detections").grid(row=0, column=3, padx=1)
                self.btnExit = Button(topFrame, pady=1, bd=4, fg="black", font=('arial', 16, 'bold'), padx=24,
                                       width=10, command = VCChoose, text="Volume contoller").grid(row=0, column=4, padx=1)
                self.btnExit = Button(topFrame, pady=1, bd=4, fg="black", font=('arial', 16, 'bold'), padx=24,
                                       width=10, command = Exit, text="Exit").grid(row=0, column=5, padx=1)

                #creation of Send Response button to call client_sends function
                self.btnResponse = Button(topFrame1, pady=1, bd=4, fg="black", font=('arial', 16, 'bold'), padx=24,
                                      width=20, command = client_sends, text="Send").grid(row=0, column=0, padx=1)
                #mainloop of python GUI
                self.root.mainloop()
            except:
                pass
            #=======================================================================================================
            
            #=======================================================================================================
            #=======================================================================================================
    except:
        pass

#creation of Home class
class Home:
    #try to handle errors
    try:
        def __init__(self, user_name):
            #creation of Home screen GUI
            self.root1 = Tk()
            self.root1.title("Home Screen")
            self.root1.geometry("3000x2500+0+0")
            self.root1.configure(bg='gainsboro')

            #import image labraries
            from PIL import ImageTk, Image
            
            #creation frames
            mainFrame = Frame(self.root1, bd=10, width=690, height=650, relief=RIDGE)
            mainFrame.grid()
            mainFrame.place(rely = 0.5, relx = 0.5, anchor=CENTER)

            topFrame = Frame(mainFrame, bd=5, width=850, height=600, relief=RIDGE)
            topFrame.grid(row=1, column=0)

            topFrame1 = Frame(mainFrame, bd=5, width=850, height=600, relief=RIDGE)
            topFrame1.grid(row=4, column=0)
            
            #creation of image frame canvas
            canvas = Canvas(topFrame, width=642, height=330)
            canvas.pack()
            img = ImageTk.PhotoImage(Image.open('2.jpg'))
            canvas.create_image(0, 0, anchor=NW, image=img)
            #creation of labels
            self.label2 = Label(mainFrame, bg='gainsboro', font=('arial',20,'bold'), padx=6,pady=2,text="ARTIFICIALLY INTELLIGENCE RECOGNITION")
            self.label2.grid(row=2, column=0)
            self.label2 = Label(mainFrame, bg='gainsboro', font=('arial',20,'bold'), padx=6,pady=2,text="SYSTEM")
            self.label2.grid(row=3, column=0)
            # =======================================================================================================
            #defining activate function
            def active(): 
                #destroy Home class GUI
                self.root1.destroy()
                #calling SigningDisplay class
                SigningDisplay(user_name)

            #defining types funtion
            def types(): 
                #destroy Home class GUI
                self.root1.destroy()
                #calling TypingDiplay class
                TypingDisplay(user_name)

            #defining Exit function
            def Exit():
                Exit = tkinter.messagebox.askyesno("SIGNING SCREEN", "confirm if you want to exit")
                if Exit>0:
                    self.root1.destroy()
                    return
            #=======================================================================================================
            #creation of Type button to call types function
            btnType = Button(topFrame1, pady=1, bd=4, fg="black", font=('arial', 16, 'bold'), padx=24,
                                  command = types, width=20, text="Hand Recognition").grid(row=0, column=0, padx=1)
            #creation of Sign button to call active function
            btnSign = Button(topFrame1, pady=1, bd=4, fg="black", font=('arial', 16, 'bold'), padx=24,
                                  command = active, width=20, text="Facial Recognition").grid(row=0, column=1, padx=1)
            #mainloop for Home screen GUI
            self.root1.mainloop()
            #=======================================================================================================
            #=======================================================================================================
            #=======================================================================================================
    except:
        pass
#creation of signup class
class signup:
    def __init__(self):
        #Creation of signup screen GUI
        self.signup_window=Tk()
        self.signup_window.geometry("3000x2500")
        
        #creation of frames
        mainFrame = Frame(self.signup_window, bd=5, width=299, height=249, relief=RIDGE)
        mainFrame.grid(row=2, column=0)
        mainFrame.place(rely = 0.4, relx = 0.5, anchor=CENTER)
        
        topFrame = Frame(self.signup_window, bd=6, width=400, height=300, relief=RIDGE)
        topFrame.grid(row=1, column=0)
        topFrame.place(rely = 0.2875, relx = 0.5, anchor=CENTER)
        
        #Creation of labels
        self.labelValue5=Label(topFrame, bg='lightblue', text="Register",font="times 20")
        self.labelValue5.grid(row=1,column=0)  

        #defining  signup_database function to store data in database
        def signup_database():
            #if statements for system authontication
            if entryValue1.get()=="":
                tkinter.messagebox.showwarning("Invalid","Enter Name")
                return
            if entryValue1.get().isdigit():
                tkinter.messagebox.showwarning("Invalid","Numbers are not allowed in name field")
                return
            if len(str(entryValue1.get())) < 3:
                tkinter.messagebox.showwarning("Invalid","Name is too short")
                return
            
            if entryValue2.get()=="":
                tkinter.messagebox.showwarning("Invalid","Enter email")
                return
            if len(entryValue2.get())>7:
                if re.match("^([a-zA-Z0-9_\-\.]+)@([a-zA-Z0-9_\-\.]+)\.([a-zA-Z]{2,5})$",entryValue2.get()):
                    pass
                else:
                    tkinter.messagebox.showwarning("Alert","Enter valid email")
                    return
            else:
                tkinter.messagebox.showwarning("Alert","Email length is too small")
                return
            
            if entryValue3.get()=="":
                tkinter.messagebox.showwarning("Invalid","Enter password")
                return
            if len(entryValue3.get())>=8:
                if re.match("^(?=.*[0-9])(?=.*[a-z])(?=.*[A-Z](?=.*[^a-bA-B0-9]))",entryValue3.get()):
                    pass
                else:   
                    tkinter.messagebox.showwarning("Invalid","Make sure your password is strong (e.g Ab2ct@ujj!)")
                    return
            else:
                tkinter.messagebox.showwarning("Invalid","Password is short! 8 values or more")
                return
            #connecting to sqlite3 database
            conn=sqlite3.connect("1.db")
            cur=conn.cursor()
            #create database
            cur.execute("CREATE TABLE IF NOT EXISTS test(id INTEGER PRIMARY KEY,name text,email text, password text)")
            cur.execute("INSERT INTO test Values(Null,?,?,?)",(entryValue1.get(),entryValue2.get(),entryValue3.get()))
            conn.commit()
            #close connection
            conn.close()
            tkinter.messagebox.showwarning("Login","Successfully Registered")
            self.signup_window.destroy()
            #calling login function
            logins()

        #creation of labels
        labelValue1=Label(mainFrame,text="Name",font="times 20")
        labelValue1.grid(row=1,column=1)
        labelValue2=Label(mainFrame,text="Email",font="times 20")
        labelValue2.grid(row=2,column=1)
        labelValue3=Label(mainFrame,text="Password",font="times 20")
        labelValue3.grid(row=3,column=1)


        #creation of text entry fields
        name_text=StringVar()
        entryValue1=Entry(mainFrame,textvariable=name_text)
        entryValue1.grid(row=1,column=2)
        email_text=StringVar()
        entryValue2=Entry(mainFrame,textvariable=email_text)
        entryValue2.grid(row=2,column=2)
        password_text=StringVar()
        entryValue3=Entry(mainFrame,textvariable=password_text)
        entryValue3.grid(row=3,column=2)

        #creation of submit button to call signup_database function
        button1=Button(mainFrame, bg='royalblue', text="submit",width=19,command=signup_database)
        button1.grid(row=4,column=2)
        #mainloop for signup GUI
        self.signup_window.mainloop()

#creation of logins function
class logins:
    def __init__(self):
        #creation login screen GUI
        self.window=Tk()
        self.window.geometry("3000x2500")
        self.window.title("Login")
        
        #import image labraries
        from PIL import ImageTk, Image
        
        #creation of frames
        mainFrame = Frame(self.window, bd=5, width=299, height=249, relief=RIDGE)
        mainFrame.grid(row=2, column=0)
        mainFrame.place(rely = 0.4, relx = 0.5, anchor=CENTER)
        
        topFrame = Frame(self.window, bd=6, width=400, height=300, relief=RIDGE)
        topFrame.grid(row=1, column=0)
        topFrame.place(rely = 0.274, relx = 0.5, anchor=CENTER)
        
        #creation labels
        self.labelValue1=Label(topFrame, bg='darkgray', text="Login",font="times 20")
        self.labelValue1.grid(row=1,column=0)    
        
        self.labelValue11=Label(mainFrame,text="email",font="times 20")
        self.labelValue11.grid(row=2,column=0)
        self.labelValue2=Label(mainFrame,text="password",font="times 20")
        self.labelValue2.grid(row=3,column=0)
        self.labelValue3=Label(mainFrame,font="times 20")
        self.labelValue3.grid(row=4,column=0)
        
        #creation of text entry fields
        email_text=StringVar()
        self.entryValue1=Entry(mainFrame,textvariable=email_text)
        self.entryValue1.grid(row=2,column=1)
        password_text=StringVar()
        self.entryValue2=Entry(mainFrame,textvariable=password_text)
        self.entryValue2.grid(row=3,column=1)

        #defining signu fuction
        def signu():
            self.window.destroy()
            #calling signup classs
            signup()

        #defining login fuction
        def login():
            #if statements to test wheather inputs are entered or not
            if self.entryValue1.get()=="":
                tkinter.messagebox.showwarning("Invalid","Enter email")
                return
            if self.entryValue2.get()=="":
                tkinter.messagebox.showwarning("Invalid","Enter password")
                return
            #creating connection for sqllite3
            conn=sqlite3.connect("1.db")
            cur=conn.cursor()
            #selection query to select contents from database where email and password = to entered ones
            cur.execute("SELECT * FROM test WHERE email=? AND password=?",(self.entryValue1.get(),self.entryValue2.get()))
            row=cur.fetchall()
            conn.close()
            print(row)
            #veryfying wheather inputed data is valid from database of not
            if row == []:
                tkinter.messagebox.showwarning("Invalid","Incorrent password or email")
                return
            if row!=[]:
                user_name=row[0][1]
                tkinter.messagebox.showwarning("Login","hellow "+user_name+" you successfully loged in")
                self.window.destroy()
                #call Home class
                Home(user_name)

        #creation of Login button to call login function
        button1=Button(mainFrame, bg='steelblue', text="Login",width=17,command=login)
        button1.grid(row=5,column=1)
        #creation of Signupup button to call signu function
        button2=Button(mainFrame, bg='gray', text="Signup",width=17,command=signu)
        button2.grid(row=6,column=1)

        #mainloop for login GUI
        self.window.mainloop()
#main function
if __name__=='__main__':
    #calling Logins class
    application = logins()
# Out:
# importing Jupyter notebook from HandTrackingModule5.ipynb
# Loading..........
# Have a passion!!
# mlp 0.9888888888888889
# mlp1 0.9888888888888889
# [(4, 'User', 'user@gmail.com', '123@Abcde')]
# b'User' has connected to the chat room
#
# You are now connected!
# ['\n']
